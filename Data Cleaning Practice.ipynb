# %% [markdown]
# # Overview
#
# The main aim of this project is to perform some data cleaning in the [JBeans Raw Dataset](https://drive.google.com/drive/folders/1giaGOhJYWIXfZzy-zxmbrUIOB9Y_ROdu) and get it ready for cleaning
#
# The main aim of this project is to practice some of the skills I have learnt in data cleaning and data analysis.
#
#
# #### Requirements
#
# The directory of this notebook contains a CSV file which contains all the raw data in the Jeans Raw Dataset. If the CSV file is missing you can download it [here](https://drive.google.com/drive/folders/1giaGOhJYWIXfZzy-zxmbrUIOB9Y_ROdu).
#
# The following assumptions have been made:
# - The CSV file is in the current directory
# - The CSV file is named raw_survey_data.csv

# %%
# if raw_survey_data.csv is in the current directory it would be outputed when you run 
# this cell 

# !ls | grep raw_survey_data.csv$
# Out:
# raw_survey_data.csv

# %%
# importing packages with their natural alias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# Here we store all the constants we need in this project
CSV_FILENAME = 'raw_survey_data.csv'

# %%
# Loading the CSV to a dataframe
raw_data = pd.read_csv(CSV_FILENAME, dtype=np.object)

# %%
# Performing basic checks on the data 
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19835 entries, 0 to 19834
# Columns: 284 entries, Unnamed: 0 to What country do you live in?
# dtypes: object(284)
# memory usage: 43.0+ MB

# %%
raw_data.columns
# Out:
# Index(['Unnamed: 0',
#        'Is Python the main language you use for your current projects?',
#        'None:What other language(s) do you use?',
#        'Java:What other language(s) do you use?',
#        'JavaScript:What other language(s) do you use?',
#        'C/C++:What other language(s) do you use?',
#        'PHP:What other language(s) do you use?',
#        'C#:What other language(s) do you use?',
#        'Ruby:What other language(s) do you use?',
#        'Bash / Shell:What other language(s) do you use?',
#        ...
#        'Technical support:Which of the following best describes your job role(s)?',
#        'Data analyst:Which of the following best describes your job role(s)?',
#        'Business analyst:Which of the following best describes your job role(s)?',
#        'Team lead:Which of the following best describes your job role(s)?',
#        'Product manager:Which of the following best describes your job role(s)?',
#        'CIO / CEO / CTO:Which of the following best describes your job role(s)?',
#        'Systems analyst:Which of the following best describes your job role(s)?',
#        'Other  Write In::Which of the following best describes your job role(s)?',
#        'Could you tell us your age range?', 'What country do you live in?'],
#       dtype='object', length=284)

# %%
raw_data.shape
# Out:
# (19835, 284)

# %%
raw_data.head()
# Out:
#   Unnamed: 0 Is Python the main language you use for your current projects?  \
# 0          1     No, I don’t use Python for my current projects
# 1          2     No, I don’t use Python for my current projects
# 2          3     No, I don’t use Python for my current projects
# 3          4     No, I don’t use Python for my current projects
# 4          5     No, I don’t use Python for my current projects
#
#   None:What other language(s) do you use?  \
# 0                                    None
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Java:What other language(s) do you use?  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                    Java
# 4                                    Java
#
#   JavaScript:What other language(s) do you use?  \
# 0                                           NaN
# 1                                    JavaScript
# 2                                    JavaScript
# 3                                    JavaScript
# 4                                           NaN
#
#   C/C++:What other language(s) do you use?  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   PHP:What other language(s) do you use?  \
# 0                                    NaN
# 1                                    PHP
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   C#:What other language(s) do you use?  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Ruby:What other language(s) do you use?  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Bash / Shell:What other language(s) do you use?  \
# 0                                             NaN
# 1                                    Bash / Shell
# 2                                    Bash / Shell
# 3                                    Bash / Shell
# 4                                             NaN
#
#               ...               \
# 0             ...
# 1             ...
# 2             ...
# 3             ...
# 4             ...
#
#   Technical support:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Data analyst:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Business analyst:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Team lead:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Product manager:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CIO / CEO / CTO:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Systems analyst:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Other  Write In::Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Could you tell us your age range? What country do you live in?
# 0                             50–59          Antigua and Barbuda
# 1                             30–39                        Italy
# 2                             50–59                United States
# 3                             30–39               United Kingdom
# 4                             21–29                United States
#
# [5 rows x 284 columns]

# %%
# List of all columns that were asked

for index, columns in enumerate(raw_data.columns):
    print('#{}: {}'.format(index+1,  columns))
# Out:
# #1: Unnamed: 0
# #2: Is Python the main language you use for your current projects?
# #3: None:What other language(s) do you use?
# #4: Java:What other language(s) do you use?
# #5: JavaScript:What other language(s) do you use?
# #6: C/C++:What other language(s) do you use?
# #7: PHP:What other language(s) do you use?
# #8: C#:What other language(s) do you use?
# #9: Ruby:What other language(s) do you use?
# #10: Bash / Shell:What other language(s) do you use?
# #11: Objective-C:What other language(s) do you use?
# #12: Go:What other language(s) do you use?
# #13: Visual Basic:What other language(s) do you use?
# #14: Scala:What other language(s) do you use?
# #15: SQL:What other language(s) do you use?
# #16: Kotlin:What other language(s) do you use?
# #17: R:What other language(s) do you use?
# #18: Swift:What other language(s) do you use?
# #19: Clojure:What other language(s) do you use?
# #20: Perl:What other language(s) do you use?
# #21: Rust:What other language(s) do you use?
# #22: Groovy:What other language(s) do you use?
# #23: TypeScript:What other language(s) do you use?
# #24: CoffeeScript:What other language(s) do you use?
# #25: HTML/CSS:What other language(s) do you use?
# #26: Other - Write In::What other language(s) do you use?
# #27: For what purposes do you mainly use Python?
# #28: Educational purposes:What do you use Python for?
# #29: Data analysis:What do you use Python for?
# #30: DevOps / System administration / Writing automation scripts:What do you use Python for?
# #31: Software testing / Writing automated tests:What do you use Python for?
# #32: Software prototyping:What do you use Python for?
# #33: Web development:What do you use Python for?
# #34: Machine learning:What do you use Python for?
# #35: Mobile development:What do you use Python for?
# #36: Desktop development:What do you use Python for?
# #37: Computer graphics:What do you use Python for?
# #38: Network programming:What do you use Python for?
# #39: Game development:What do you use Python for?
# #40: Multimedia applications development:What do you use Python for?
# #41: Embedded development:What do you use Python for?
# #42: Programming of web parsers / scrapers / crawlers:What do you use Python for?
# #43: Other - Write In::What do you use Python for?
# #44: Educational purposes:To what extent are you involvedin the following activities?
# #45: Data analysis:To what extent are you involvedin the following activities?
# #46: DevOps / System administration / Writing automation scripts:To what extent are you involvedin the following activities?
# #47: Software testing / Writing automated tests:To what extent are you involvedin the following activities?
# #48: Software prototyping:To what extent are you involvedin the following activities?
# #49: Web development:To what extent are you involvedin the following activities?
# #50: Machine learning:To what extent are you involvedin the following activities?
# #51: Mobile development:To what extent are you involvedin the following activities?
# #52: Desktop development:To what extent are you involvedin the following activities?
# #53: Computer graphics:To what extent are you involvedin the following activities?
# #54: Network programming:To what extent are you involvedin the following activities?
# #55: Game development:To what extent are you involvedin the following activities?
# #56: Multimedia applications development:To what extent are you involvedin the following activities?
# #57: Embedded development:To what extent are you involvedin the following activities?
# #58: Programming of web parsers / scrapers / crawlers:To what extent are you involvedin the following activities?
# #59: Other - Write In::To what extent are you involvedin the following activities?
# #60: What do you use Python for the most?
# #61: Do you consider yourself as a Data-Scientist?
# #62: Which version of Python do you use the most?
# #63: Which version of Python 2 do you use the most?
# #64: Which version of Python 3 do you use the most?
# #65: I dont update:What do you typically use to upgrade your Python version?
# #66: Somebody else manages Python updates for me:What do you typically use to upgrade your Python version?
# #67: Python.org:What do you typically use to upgrade your Python version?
# #68: Build from source:What do you typically use to upgrade your Python version?
# #69: Automatic upgrade via cloud provider:What do you typically use to upgrade your Python version?
# #70: Enthought:What do you typically use to upgrade your Python version?
# #71: Anaconda:What do you typically use to upgrade your Python version?
# #72: ActivePython:What do you typically use to upgrade your Python version?
# #73: Intel Distribution for Python:What do you typically use to upgrade your Python version?
# #74: OS-provided Python (via apt-get, yum, homebrew, etc.):What do you typically use to upgrade your Python version?
# #75: pyenv:What do you typically use to upgrade your Python version?
# #76: pythonz:What do you typically use to upgrade your Python version?
# #77: I use Docker containers:What do you typically use to upgrade your Python version?
# #78: Other  Write In::What do you typically use to upgrade your Python version?
# #79: None:Do you use any of the following tools to isolate Python environments, if any?
# #80: Virtualenv / pipenv:Do you use any of the following tools to isolate Python environments, if any?
# #81: Conda:Do you use any of the following tools to isolate Python environments, if any?
# #82: Docker:Do you use any of the following tools to isolate Python environments, if any?
# #83: Vagrant  / virtual machines:Do you use any of the following tools to isolate Python environments, if any?
# #84: Other  Write In::Do you use any of the following tools to isolate Python environments, if any?
# #85: None:What web frameworks / libraries do you use in addition to Python?
# #86: Django:What web frameworks / libraries do you use in addition to Python?
# #87: TurboGears:What web frameworks / libraries do you use in addition to Python?
# #88: web2py:What web frameworks / libraries do you use in addition to Python?
# #89: Bottle:What web frameworks / libraries do you use in addition to Python?
# #90: CherryPy:What web frameworks / libraries do you use in addition to Python?
# #91: Flask:What web frameworks / libraries do you use in addition to Python?
# #92: Hug:What web frameworks / libraries do you use in addition to Python?
# #93: Pyramid:What web frameworks / libraries do you use in addition to Python?
# #94: Tornado:What web frameworks / libraries do you use in addition to Python?
# #95: Falcon:What web frameworks / libraries do you use in addition to Python?
# #96: Other  Write In::What web frameworks / libraries do you use in addition to Python?
# #97: None:What data science framework(s) do you use in addition to Python?
# #98: NumPy:What data science framework(s) do you use in addition to Python?
# #99: SciPy:What data science framework(s) do you use in addition to Python?
# #100: Pandas:What data science framework(s) do you use in addition to Python?
# #101: Matplotlib:What data science framework(s) do you use in addition to Python?
# #102: Seaborn:What data science framework(s) do you use in addition to Python?
# #103: SciKit-Learn:What data science framework(s) do you use in addition to Python?
# #104: Keras:What data science framework(s) do you use in addition to Python?
# #105: TensorFlow:What data science framework(s) do you use in addition to Python?
# #106: Theano:What data science framework(s) do you use in addition to Python?
# #107: NLTK:What data science framework(s) do you use in addition to Python?
# #108: Gensim:What data science framework(s) do you use in addition to Python?
# #109: Other - Write In::What data science framework(s) do you use in addition to Python?
# #110: None:Which of the following frameworks / libraries do you use in addition to Python?
# #111: Requests:Which of the following frameworks / libraries do you use in addition to Python?
# #112: aiohttp:Which of the following frameworks / libraries do you use in addition to Python?
# #113: PyQT:Which of the following frameworks / libraries do you use in addition to Python?
# #114: PyGTK:Which of the following frameworks / libraries do you use in addition to Python?
# #115: wxPython:Which of the following frameworks / libraries do you use in addition to Python?
# #116: Pillow:Which of the following frameworks / libraries do you use in addition to Python?
# #117: Tkinter:Which of the following frameworks / libraries do you use in addition to Python?
# #118: Pygame:Which of the following frameworks / libraries do you use in addition to Python?
# #119: Twisted:Which of the following frameworks / libraries do you use in addition to Python?
# #120: Asyncio:Which of the following frameworks / libraries do you use in addition to Python?
# #121: Kivy:Which of the following frameworks / libraries do you use in addition to Python?
# #122: Six:Which of the following frameworks / libraries do you use in addition to Python?
# #123: Scrapy:Which of the following frameworks / libraries do you use in addition to Python?
# #124: Other  Write In::Which of the following frameworks / libraries do you use in addition to Python?
# #125: None:Which of the following cloud platforms do you use?
# #126: Google Cloud Platform:Which of the following cloud platforms do you use?
# #127: AWS:Which of the following cloud platforms do you use?
# #128: Microsoft Azure:Which of the following cloud platforms do you use?
# #129: Rackspace:Which of the following cloud platforms do you use?
# #130: Heroku:Which of the following cloud platforms do you use?
# #131: DigitalOcean:Which of the following cloud platforms do you use?
# #132: Linode:Which of the following cloud platforms do you use?
# #133: PythonAnywhere:Which of the following cloud platforms do you use?
# #134: OpenShift:Which of the following cloud platforms do you use?
# #135: OpenStack:Which of the following cloud platforms do you use?
# #136: Other  Write In::Which of the following cloud platforms do you use?
# #137: None of the following:How do you run code in the cloud (in the production environment)?
# #138: In virtual machines:How do you run code in the cloud (in the production environment)?
# #139: Within containers:How do you run code in the cloud (in the production environment)?
# #140: On a Platform-as-a-Service (such as Heroku or Google App Engine):How do you run code in the cloud (in the production environment)?
# #141: Serverless (such as AWS Lambda or Cloud Functions):How do you run code in the cloud (in the production environment)?
# #142: Other  Write In::How do you run code in the cloud (in the production environment)?
# #143: None of the following:How do you develop for the cloud?
# #144: With local system interpreter:How do you develop for the cloud?
# #145: Locally with virtualenv (or similar):How do you develop for the cloud?
# #146: In Docker containers:How do you develop for the cloud?
# #147: In virtual machines:How do you develop for the cloud?
# #148: In remote development environments:How do you develop for the cloud?
# #149: Directly in the production environment:How do you develop for the cloud?
# #150: Other  Write In::How do you develop for the cloud?
# #151: Windows:What operating system(s) are your development environment?
# #152: Linux:What operating system(s) are your development environment?
# #153: macOS:What operating system(s) are your development environment?
# #154: BSD:What operating system(s) are your development environment?
# #155: Other  Write In::What operating system(s) are your development environment?
# #156: None:Which Python unit-testing framework(s) do you use, if any?
# #157: pytest:Which Python unit-testing framework(s) do you use, if any?
# #158: nose:Which Python unit-testing framework(s) do you use, if any?
# #159: unittest:Which Python unit-testing framework(s) do you use, if any?
# #160: doctest:Which Python unit-testing framework(s) do you use, if any?
# #161: Tox:Which Python unit-testing framework(s) do you use, if any?
# #162: Hypothesis:Which Python unit-testing framework(s) do you use, if any?
# #163: mock:Which Python unit-testing framework(s) do you use, if any?
# #164: Other  Write In::Which Python unit-testing framework(s) do you use, if any?
# #165: None:What ORM(s) do you use together with Python, if any?
# #166: Django ORM:What ORM(s) do you use together with Python, if any?
# #167: SQLAlchemy:What ORM(s) do you use together with Python, if any?
# #168: Peewee:What ORM(s) do you use together with Python, if any?
# #169: Dejavu:What ORM(s) do you use together with Python, if any?
# #170: PonyORM:What ORM(s) do you use together with Python, if any?
# #171: SQLObject:What ORM(s) do you use together with Python, if any?
# #172: Tortoise ORM:What ORM(s) do you use together with Python, if any?
# #173: Other  Write In::What ORM(s) do you use together with Python, if any?
# #174: None:Which database(s) do you regularly use, if any?
# #175: DB2:Which database(s) do you regularly use, if any?
# #176: MS SQL Server:Which database(s) do you regularly use, if any?
# #177: MySQL:Which database(s) do you regularly use, if any?
# #178: Oracle Database:Which database(s) do you regularly use, if any?
# #179: PostgreSQL:Which database(s) do you regularly use, if any?
# #180: SQLite:Which database(s) do you regularly use, if any?
# #181: Cassandra:Which database(s) do you regularly use, if any?
# #182: Couchbase:Which database(s) do you regularly use, if any?
# #183: HBase:Which database(s) do you regularly use, if any?
# #184: MongoDB:Which database(s) do you regularly use, if any?
# #185: Neo4j:Which database(s) do you regularly use, if any?
# #186: Redis:Which database(s) do you regularly use, if any?
# #187: Amazon Redshift:Which database(s) do you regularly use, if any?
# #188: h2:Which database(s) do you regularly use, if any?
# #189: Other  Write In::Which database(s) do you regularly use, if any?
# #190: None:Which of the following Big Data tool(s) do you use, if any?
# #191: Apache Beam:Which of the following Big Data tool(s) do you use, if any?
# #192: Apache Flink:Which of the following Big Data tool(s) do you use, if any?
# #193: Apache Hadoop/MapReduce:Which of the following Big Data tool(s) do you use, if any?
# #194: Apache Hive:Which of the following Big Data tool(s) do you use, if any?
# #195: Apache Samza:Which of the following Big Data tool(s) do you use, if any?
# #196: Apache Kafka:Which of the following Big Data tool(s) do you use, if any?
# #197: Apache Spark:Which of the following Big Data tool(s) do you use, if any?
# #198: Apache Tez:Which of the following Big Data tool(s) do you use, if any?
# #199: Dask:Which of the following Big Data tool(s) do you use, if any?
# #200: ClickHouse:Which of the following Big Data tool(s) do you use, if any?
# #201: Other  Write In::Which of the following Big Data tool(s) do you use, if any?
# #202: None:Which Continuous Integration (CI) system(s) do you regularly use?
# #203: Jenkins / Hudson:Which Continuous Integration (CI) system(s) do you regularly use?
# #204: TeamCity:Which Continuous Integration (CI) system(s) do you regularly use?
# #205: Bamboo:Which Continuous Integration (CI) system(s) do you regularly use?
# #206: Travis CI:Which Continuous Integration (CI) system(s) do you regularly use?
# #207: CircleCI:Which Continuous Integration (CI) system(s) do you regularly use?
# #208: CruiseControl:Which Continuous Integration (CI) system(s) do you regularly use?
# #209: Gitlab CI:Which Continuous Integration (CI) system(s) do you regularly use?
# #210: AppVeyor:Which Continuous Integration (CI) system(s) do you regularly use?
# #211: Other  Write In::Which Continuous Integration (CI) system(s) do you regularly use?
# #212: None:Which configuration management tools do you use, if any?
# #213: Salt:Which configuration management tools do you use, if any?
# #214: Puppet:Which configuration management tools do you use, if any?
# #215: Chef:Which configuration management tools do you use, if any?
# #216: Ansible:Which configuration management tools do you use, if any?
# #217: Custom solution:Which configuration management tools do you use, if any?
# #218: Other  Write In::Which configuration management tools do you use, if any?
# #219: What is the main editor you use for your current Python development?
# #220: None:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #221: PyCharm Professional Edition:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #222: PyCharm Community Edition:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #223: Sublime Text:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #224: Vim:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #225: Atom:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #226: VS Code:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #227: Eclipse + Pydev:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #228: Aptana:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #229: Jupyter Notebook:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #230: IntelliJ IDEA:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #231: NotePad++:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #232: IDLE:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #233: Emacs:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #234: Python Tools for Visual Studio (PTVS):What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #235: NetBeans:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #236: Spyder:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #237: Rodeo:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #238: Gedit:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #239: Ninja-IDE:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #240: Komodo Editor:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #241: Komodo IDE:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #242: Wing IDE:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #243: TextMate:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #244: None:What editors/IDEs do you usefor Python development in addition to your main ide/editor?_1
# #245: Other  Write In::What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #246: Do youregularly work on multiple projects at the same time?
# #247: use autocompletion  in your editor:When developing in Python, how often do you ?
# #248: use a debugger:When developing in Python, how often do you ?
# #249: refactor your code:When developing in Python, how often do you ?
# #250: use Version Control Systems:When developing in Python, how often do you ?
# #251: use code linting (programs that analyze code for potential errors):When developing in Python, how often do you ?
# #252: use Python virtual environments for your projects:When developing in Python, how often do you ?
# #253: use SQL databases :When developing in Python, how often do you ?
# #254: use NoSQL databases:When developing in Python, how often do you ?
# #255: run / debug or edit code on remote machines (remote hosts, VMs, etc.):When developing in Python, how often do you ?
# #256: use a Python profiler:When developing in Python, how often do you ?
# #257: write tests for your code:When developing in Python, how often do you ?
# #258: use code coverage:When developing in Python, how often do you ?
# #259: use optional type hinting:When developing in Python, how often do you ?
# #260: use Continuous Integration tools:When developing in Python, how often do you ?
# #261: use Issue Trackers:When developing in Python, how often do you ?
# #262: How did you first learn aboutyour main ide/editor?
# #263: How often do you use your main ide/editor?
# #264: Most of the time, do you ...?
# #265: How many people are in your project team?
# #266: What is your employment status?
# #267: How many people work for your company / organization?
# #268: Choose one from the list::Which of the following industries best describes your company's business?
# #269: Choose one from the list::Which of the following industries do you develop for?
# #270: How long have you been working in the IT industry?
# #271: DBA:Which of the following best describes your job role(s)?
# #272: Architect:Which of the following best describes your job role(s)?
# #273: QA engineer:Which of the following best describes your job role(s)?
# #274: Developer / Programmer:Which of the following best describes your job role(s)?
# #275: Technical support:Which of the following best describes your job role(s)?
# #276: Data analyst:Which of the following best describes your job role(s)?
# #277: Business analyst:Which of the following best describes your job role(s)?
# #278: Team lead:Which of the following best describes your job role(s)?
# #279: Product manager:Which of the following best describes your job role(s)?
# #280: CIO / CEO / CTO:Which of the following best describes your job role(s)?
# #281: Systems analyst:Which of the following best describes your job role(s)?
# #282: Other  Write In::Which of the following best describes your job role(s)?
# #283: Could you tell us your age range?
# #284: What country do you live in?

# %% [markdown]
# ###  Characteristics of the Dataset
# We see from the above checks that the:
#
# - dataset has `19,835` rows and `284` columns
# - questions asked were placed in columns
# - each option in a multi-choice question is stored as a new column in the dataset
# - missing values are stored as `NaN`
# - once the user says they dont use python as their main language for the first question then the only relevant question for that user is the last 2 namely:
#
# >Could you tell us your age range?
#
# **AND**
#
# >What country do you live in?

# %% [markdown]
# ### Our goal
#
# Looking at how the data is structured, I think that the best way to structure this data for analysis is to extract the answers of each question and store them in different sheets in an excel file with each sheet having the name of the excel files.
#
# This, I believe would make it easy to analyze and process the data.
#
# In summary, we have to do the following:
# - each question and extract their answers
# - clean data extracted and get it ready for analysis
# - export cleaned data into an excel sheet whose sheet name is the question
# - save the data to a file
#
# The final output of this notebook therefore is the excel_file. Let us start by creating 2 subsets of the origin dataframe that contains:
# - Answers to questions when the user uses python
# - Answers to questions when the user does not use python

# %% [markdown]
# ### Question 1
#
# The first question is what we would use to create two observation subsets

# %%
# observations for python files that do not have
NOT_PYTHON_STR = 'No, I don’t use Python for my current projects'

# %%
# extracting the observations into two dataframes
NON_PYTHON_OBSERVATIONS_DF = raw_data[raw_data.iloc[:, 1] == NOT_PYTHON_STR]
PYTHON_OBSERVATIONS_DF = raw_data[raw_data.iloc[:, 1] != NOT_PYTHON_STR]

# %%
print(NON_PYTHON_OBSERVATIONS_DF.iloc[:, 1].value_counts())
NON_PYTHON_OBSERVATIONS_DF.head()
# Out:
# No, I don’t use Python for my current projects    1404
# Name: Is Python the main language you use for your current projects?, dtype: int64
#   Unnamed: 0 Is Python the main language you use for your current projects?  \
# 0          1     No, I don’t use Python for my current projects
# 1          2     No, I don’t use Python for my current projects
# 2          3     No, I don’t use Python for my current projects
# 3          4     No, I don’t use Python for my current projects
# 4          5     No, I don’t use Python for my current projects
#
#   None:What other language(s) do you use?  \
# 0                                    None
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Java:What other language(s) do you use?  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                    Java
# 4                                    Java
#
#   JavaScript:What other language(s) do you use?  \
# 0                                           NaN
# 1                                    JavaScript
# 2                                    JavaScript
# 3                                    JavaScript
# 4                                           NaN
#
#   C/C++:What other language(s) do you use?  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   PHP:What other language(s) do you use?  \
# 0                                    NaN
# 1                                    PHP
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   C#:What other language(s) do you use?  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Ruby:What other language(s) do you use?  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Bash / Shell:What other language(s) do you use?  \
# 0                                             NaN
# 1                                    Bash / Shell
# 2                                    Bash / Shell
# 3                                    Bash / Shell
# 4                                             NaN
#
#               ...               \
# 0             ...
# 1             ...
# 2             ...
# 3             ...
# 4             ...
#
#   Technical support:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Data analyst:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Business analyst:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Team lead:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Product manager:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CIO / CEO / CTO:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Systems analyst:Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Other  Write In::Which of the following best describes your job role(s)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Could you tell us your age range? What country do you live in?
# 0                             50–59          Antigua and Barbuda
# 1                             30–39                        Italy
# 2                             50–59                United States
# 3                             30–39               United Kingdom
# 4                             21–29                United States
#
# [5 rows x 284 columns]

# %%
print(PYTHON_OBSERVATIONS_DF.iloc[:, 1].value_counts())
PYTHON_OBSERVATIONS_DF.head()
# Out:
# Yes                                         15404
# No, I use Python as a secondary language     3027
# Name: Is Python the main language you use for your current projects?, dtype: int64
#      Unnamed: 0  \
# 1404       1405
# 1405       1406
# 1406       1407
# 1407       1408
# 1408       1409
#
#      Is Python the main language you use for your current projects?  \
# 1404                                                Yes
# 1405                                                Yes
# 1406                                                Yes
# 1407                                                Yes
# 1408                                                Yes
#
#      None:What other language(s) do you use?  \
# 1404                                     NaN
# 1405                                     NaN
# 1406                                     NaN
# 1407                                     NaN
# 1408                                     NaN
#
#      Java:What other language(s) do you use?  \
# 1404                                    Java
# 1405                                     NaN
# 1406                                     NaN
# 1407                                     NaN
# 1408                                     NaN
#
#      JavaScript:What other language(s) do you use?  \
# 1404                                    JavaScript
# 1405                                    JavaScript
# 1406                                    JavaScript
# 1407                                           NaN
# 1408                                    JavaScript
#
#      C/C++:What other language(s) do you use?  \
# 1404                                      NaN
# 1405                                      NaN
# 1406                                      NaN
# 1407                                      NaN
# 1408                                      NaN
#
#      PHP:What other language(s) do you use?  \
# 1404                                    NaN
# 1405                                    NaN
# 1406                                    NaN
# 1407                                    NaN
# 1408                                    NaN
#
#      C#:What other language(s) do you use?  \
# 1404                                   NaN
# 1405                                   NaN
# 1406                                   NaN
# 1407                                   NaN
# 1408                                   NaN
#
#      Ruby:What other language(s) do you use?  \
# 1404                                     NaN
# 1405                                     NaN
# 1406                                     NaN
# 1407                                     NaN
# 1408                                     NaN
#
#      Bash / Shell:What other language(s) do you use?  \
# 1404                                             NaN
# 1405                                             NaN
# 1406                                    Bash / Shell
# 1407                                    Bash / Shell
# 1408                                             NaN
#
#                  ...               \
# 1404             ...
# 1405             ...
# 1406             ...
# 1407             ...
# 1408             ...
#
#      Technical support:Which of the following best describes your job role(s)?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Data analyst:Which of the following best describes your job role(s)?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Business analyst:Which of the following best describes your job role(s)?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Team lead:Which of the following best describes your job role(s)?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                          Team lead
#
#      Product manager:Which of the following best describes your job role(s)?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      CIO / CEO / CTO:Which of the following best describes your job role(s)?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                    CIO / CEO / CTO
# 1408                                                NaN
#
#      Systems analyst:Which of the following best describes your job role(s)?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Other  Write In::Which of the following best describes your job role(s)?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Could you tell us your age range? What country do you live in?
# 1404                             40–49                United States
# 1405                             18–20                      Nigeria
# 1406                             21–29                United States
# 1407                             50–59                United States
# 1408                             40–49               United Kingdom
#
# [5 rows x 284 columns]

# %% [markdown]
# From the above we have successfully put all observations of python users into the `PYTHON_OBSERVATIONS_DF` constant and all non users into `NON_PYTHON_OBSERVATIONS_DF`
#
#
# Now we are ready to start processing our questions

# %% [markdown]
# ## Question 2
#
# In this multi choice question, the users were asked:
# > What other language(s) do you use?
#
# The options of this question spans across mulitiple columns number 2 to 25.

# %%
question_two = PYTHON_OBSERVATIONS_DF.iloc[:, 2:26]

# %%
question_two
# Out:
#       None:What other language(s) do you use?  \
# 1404                                      NaN
# 1405                                      NaN
# 1406                                      NaN
# 1407                                      NaN
# 1408                                      NaN
# 1409                                      NaN
# 1410                                      NaN
# 1411                                      NaN
# 1412                                      NaN
# 1413                                      NaN
# 1414                                      NaN
# 1415                                      NaN
# 1416                                      NaN
# 1417                                      NaN
# 1418                                      NaN
# 1419                                      NaN
# 1420                                      NaN
# 1421                                      NaN
# 1422                                      NaN
# 1423                                      NaN
# 1424                                      NaN
# 1425                                      NaN
# 1426                                      NaN
# 1427                                      NaN
# 1428                                      NaN
# 1429                                      NaN
# 1430                                     None
# 1431                                      NaN
# 1432                                      NaN
# 1433                                      NaN
# ...                                       ...
# 19805                                     NaN
# 19806                                     NaN
# 19807                                     NaN
# 19808                                    None
# 19809                                     NaN
# 19810                                     NaN
# 19811                                     NaN
# 19812                                     NaN
# 19813                                     NaN
# 19814                                     NaN
# 19815                                     NaN
# 19816                                     NaN
# 19817                                     NaN
# 19818                                     NaN
# 19819                                     NaN
# 19820                                    None
# 19821                                     NaN
# 19822                                     NaN
# 19823                                     NaN
# 19824                                     NaN
# 19825                                     NaN
# 19826                                     NaN
# 19827                                     NaN
# 19828                                     NaN
# 19829                                     NaN
# 19830                                     NaN
# 19831                                     NaN
# 19832                                    None
# 19833                                     NaN
# 19834                                     NaN
#
#       Java:What other language(s) do you use?  \
# 1404                                     Java
# 1405                                      NaN
# 1406                                      NaN
# 1407                                      NaN
# 1408                                      NaN
# 1409                                      NaN
# 1410                                     Java
# 1411                                     Java
# 1412                                      NaN
# 1413                                      NaN
# 1414                                      NaN
# 1415                                      NaN
# 1416                                      NaN
# 1417                                      NaN
# 1418                                      NaN
# 1419                                     Java
# 1420                                      NaN
# 1421                                      NaN
# 1422                                      NaN
# 1423                                      NaN
# 1424                                      NaN
# 1425                                      NaN
# 1426                                      NaN
# 1427                                      NaN
# 1428                                      NaN
# 1429                                      NaN
# 1430                                      NaN
# 1431                                      NaN
# 1432                                      NaN
# 1433                                      NaN
# ...                                       ...
# 19805                                    Java
# 19806                                     NaN
# 19807                                     NaN
# 19808                                     NaN
# 19809                                     NaN
# 19810                                     NaN
# 19811                                     NaN
# 19812                                     NaN
# 19813                                     NaN
# 19814                                     NaN
# 19815                                     NaN
# 19816                                     NaN
# 19817                                     NaN
# 19818                                     NaN
# 19819                                     NaN
# 19820                                     NaN
# 19821                                     NaN
# 19822                                     NaN
# 19823                                     NaN
# 19824                                     NaN
# 19825                                    Java
# 19826                                     NaN
# 19827                                     NaN
# 19828                                     NaN
# 19829                                    Java
# 19830                                     NaN
# 19831                                     NaN
# 19832                                     NaN
# 19833                                    Java
# 19834                                     NaN
#
#       JavaScript:What other language(s) do you use?  \
# 1404                                     JavaScript
# 1405                                     JavaScript
# 1406                                     JavaScript
# 1407                                            NaN
# 1408                                     JavaScript
# 1409                                            NaN
# 1410                                     JavaScript
# 1411                                            NaN
# 1412                                            NaN
# 1413                                            NaN
# 1414                                     JavaScript
# 1415                                     JavaScript
# 1416                                            NaN
# 1417                                            NaN
# 1418                                            NaN
# 1419                                     JavaScript
# 1420                                     JavaScript
# 1421                                     JavaScript
# 1422                                     JavaScript
# 1423                                     JavaScript
# 1424                                            NaN
# 1425                                     JavaScript
# 1426                                     JavaScript
# 1427                                     JavaScript
# 1428                                     JavaScript
# 1429                                            NaN
# 1430                                            NaN
# 1431                                            NaN
# 1432                                            NaN
# 1433                                            NaN
# ...                                             ...
# 19805                                    JavaScript
# 19806                                           NaN
# 19807                                           NaN
# 19808                                           NaN
# 19809                                           NaN
# 19810                                    JavaScript
# 19811                                    JavaScript
# 19812                                           NaN
# 19813                                           NaN
# 19814                                           NaN
# 19815                                    JavaScript
# 19816                                    JavaScript
# 19817                                    JavaScript
# 19818                                    JavaScript
# 19819                                    JavaScript
# 19820                                           NaN
# 19821                                           NaN
# 19822                                           NaN
# 19823                                           NaN
# 19824                                    JavaScript
# 19825                                    JavaScript
# 19826                                    JavaScript
# 19827                                           NaN
# 19828                                           NaN
# 19829                                           NaN
# 19830                                    JavaScript
# 19831                                           NaN
# 19832                                           NaN
# 19833                                           NaN
# 19834                                    JavaScript
#
#       C/C++:What other language(s) do you use?  \
# 1404                                       NaN
# 1405                                       NaN
# 1406                                       NaN
# 1407                                       NaN
# 1408                                       NaN
# 1409                                       NaN
# 1410                                     C/C++
# 1411                                     C/C++
# 1412                                     C/C++
# 1413                                       NaN
# 1414                                       NaN
# 1415                                       NaN
# 1416                                       NaN
# 1417                                       NaN
# 1418                                       NaN
# 1419                                       NaN
# 1420                                       NaN
# 1421                                       NaN
# 1422                                       NaN
# 1423                                       NaN
# 1424                                       NaN
# 1425                                     C/C++
# 1426                                       NaN
# 1427                                     C/C++
# 1428                                       NaN
# 1429                                     C/C++
# 1430                                       NaN
# 1431                                       NaN
# 1432                                       NaN
# 1433                                       NaN
# ...                                        ...
# 19805                                    C/C++
# 19806                                      NaN
# 19807                                      NaN
# 19808                                      NaN
# 19809                                    C/C++
# 19810                                      NaN
# 19811                                      NaN
# 19812                                      NaN
# 19813                                    C/C++
# 19814                                    C/C++
# 19815                                      NaN
# 19816                                      NaN
# 19817                                      NaN
# 19818                                      NaN
# 19819                                      NaN
# 19820                                      NaN
# 19821                                      NaN
# 19822                                      NaN
# 19823                                    C/C++
# 19824                                      NaN
# 19825                                    C/C++
# 19826                                      NaN
# 19827                                      NaN
# 19828                                      NaN
# 19829                                    C/C++
# 19830                                    C/C++
# 19831                                      NaN
# 19832                                      NaN
# 19833                                    C/C++
# 19834                                      NaN
#
#       PHP:What other language(s) do you use?  \
# 1404                                     NaN
# 1405                                     NaN
# 1406                                     NaN
# 1407                                     NaN
# 1408                                     NaN
# 1409                                     NaN
# 1410                                     NaN
# 1411                                     NaN
# 1412                                     NaN
# 1413                                     NaN
# 1414                                     PHP
# 1415                                     NaN
# 1416                                     NaN
# 1417                                     PHP
# 1418                                     NaN
# 1419                                     PHP
# 1420                                     NaN
# 1421                                     PHP
# 1422                                     NaN
# 1423                                     NaN
# 1424                                     NaN
# 1425                                     NaN
# 1426                                     NaN
# 1427                                     NaN
# 1428                                     NaN
# 1429                                     NaN
# 1430                                     NaN
# 1431                                     NaN
# 1432                                     NaN
# 1433                                     NaN
# ...                                      ...
# 19805                                    PHP
# 19806                                    NaN
# 19807                                    NaN
# 19808                                    NaN
# 19809                                    NaN
# 19810                                    NaN
# 19811                                    NaN
# 19812                                    NaN
# 19813                                    NaN
# 19814                                    NaN
# 19815                                    NaN
# 19816                                    NaN
# 19817                                    NaN
# 19818                                    NaN
# 19819                                    NaN
# 19820                                    NaN
# 19821                                    NaN
# 19822                                    NaN
# 19823                                    NaN
# 19824                                    NaN
# 19825                                    NaN
# 19826                                    NaN
# 19827                                    NaN
# 19828                                    NaN
# 19829                                    NaN
# 19830                                    NaN
# 19831                                    NaN
# 19832                                    NaN
# 19833                                    NaN
# 19834                                    NaN
#
#       C#:What other language(s) do you use?  \
# 1404                                    NaN
# 1405                                    NaN
# 1406                                    NaN
# 1407                                    NaN
# 1408                                    NaN
# 1409                                    NaN
# 1410                                    NaN
# 1411                                    NaN
# 1412                                    NaN
# 1413                                    NaN
# 1414                                    NaN
# 1415                                    NaN
# 1416                                    NaN
# 1417                                    NaN
# 1418                                    NaN
# 1419                                     C#
# 1420                                    NaN
# 1421                                    NaN
# 1422                                    NaN
# 1423                                    NaN
# 1424                                     C#
# 1425                                    NaN
# 1426                                    NaN
# 1427                                    NaN
# 1428                                    NaN
# 1429                                    NaN
# 1430                                    NaN
# 1431                                    NaN
# 1432                                     C#
# 1433                                    NaN
# ...                                     ...
# 19805                                    C#
# 19806                                   NaN
# 19807                                    C#
# 19808                                   NaN
# 19809                                   NaN
# 19810                                   NaN
# 19811                                    C#
# 19812                                   NaN
# 19813                                   NaN
# 19814                                   NaN
# 19815                                   NaN
# 19816                                   NaN
# 19817                                   NaN
# 19818                                   NaN
# 19819                                   NaN
# 19820                                   NaN
# 19821                                   NaN
# 19822                                   NaN
# 19823                                    C#
# 19824                                   NaN
# 19825                                   NaN
# 19826                                   NaN
# 19827                                   NaN
# 19828                                   NaN
# 19829                                   NaN
# 19830                                    C#
# 19831                                   NaN
# 19832                                   NaN
# 19833                                   NaN
# 19834                                   NaN
#
#       Ruby:What other language(s) do you use?  \
# 1404                                      NaN
# 1405                                      NaN
# 1406                                      NaN
# 1407                                      NaN
# 1408                                      NaN
# 1409                                      NaN
# 1410                                      NaN
# 1411                                      NaN
# 1412                                      NaN
# 1413                                      NaN
# 1414                                      NaN
# 1415                                      NaN
# 1416                                      NaN
# 1417                                     Ruby
# 1418                                      NaN
# 1419                                      NaN
# 1420                                      NaN
# 1421                                      NaN
# 1422                                      NaN
# 1423                                      NaN
# 1424                                      NaN
# 1425                                      NaN
# 1426                                      NaN
# 1427                                      NaN
# 1428                                      NaN
# 1429                                      NaN
# 1430                                      NaN
# 1431                                      NaN
# 1432                                      NaN
# 1433                                      NaN
# ...                                       ...
# 19805                                     NaN
# 19806                                     NaN
# 19807                                     NaN
# 19808                                     NaN
# 19809                                     NaN
# 19810                                     NaN
# 19811                                     NaN
# 19812                                     NaN
# 19813                                     NaN
# 19814                                     NaN
# 19815                                     NaN
# 19816                                     NaN
# 19817                                     NaN
# 19818                                     NaN
# 19819                                     NaN
# 19820                                     NaN
# 19821                                     NaN
# 19822                                     NaN
# 19823                                     NaN
# 19824                                     NaN
# 19825                                     NaN
# 19826                                     NaN
# 19827                                     NaN
# 19828                                     NaN
# 19829                                     NaN
# 19830                                     NaN
# 19831                                     NaN
# 19832                                     NaN
# 19833                                     NaN
# 19834                                    Ruby
#
#       Bash / Shell:What other language(s) do you use?  \
# 1404                                              NaN
# 1405                                              NaN
# 1406                                     Bash / Shell
# 1407                                     Bash / Shell
# 1408                                              NaN
# 1409                                     Bash / Shell
# 1410                                     Bash / Shell
# 1411                                              NaN
# 1412                                              NaN
# 1413                                     Bash / Shell
# 1414                                              NaN
# 1415                                     Bash / Shell
# 1416                                     Bash / Shell
# 1417                                     Bash / Shell
# 1418                                              NaN
# 1419                                     Bash / Shell
# 1420                                     Bash / Shell
# 1421                                     Bash / Shell
# 1422                                              NaN
# 1423                                              NaN
# 1424                                              NaN
# 1425                                     Bash / Shell
# 1426                                              NaN
# 1427                                     Bash / Shell
# 1428                                     Bash / Shell
# 1429                                     Bash / Shell
# 1430                                              NaN
# 1431                                     Bash / Shell
# 1432                                     Bash / Shell
# 1433                                              NaN
# ...                                               ...
# 19805                                    Bash / Shell
# 19806                                    Bash / Shell
# 19807                                    Bash / Shell
# 19808                                             NaN
# 19809                                             NaN
# 19810                                    Bash / Shell
# 19811                                             NaN
# 19812                                             NaN
# 19813                                             NaN
# 19814                                    Bash / Shell
# 19815                                    Bash / Shell
# 19816                                             NaN
# 19817                                             NaN
# 19818                                             NaN
# 19819                                             NaN
# 19820                                             NaN
# 19821                                             NaN
# 19822                                             NaN
# 19823                                             NaN
# 19824                                             NaN
# 19825                                    Bash / Shell
# 19826                                             NaN
# 19827                                    Bash / Shell
# 19828                                    Bash / Shell
# 19829                                             NaN
# 19830                                    Bash / Shell
# 19831                                    Bash / Shell
# 19832                                             NaN
# 19833                                             NaN
# 19834                                    Bash / Shell
#
#       Objective-C:What other language(s) do you use?  \
# 1404                                             NaN
# 1405                                             NaN
# 1406                                             NaN
# 1407                                             NaN
# 1408                                             NaN
# 1409                                             NaN
# 1410                                             NaN
# 1411                                             NaN
# 1412                                             NaN
# 1413                                             NaN
# 1414                                             NaN
# 1415                                             NaN
# 1416                                             NaN
# 1417                                             NaN
# 1418                                             NaN
# 1419                                             NaN
# 1420                                             NaN
# 1421                                             NaN
# 1422                                             NaN
# 1423                                             NaN
# 1424                                             NaN
# 1425                                             NaN
# 1426                                             NaN
# 1427                                             NaN
# 1428                                             NaN
# 1429                                             NaN
# 1430                                             NaN
# 1431                                             NaN
# 1432                                             NaN
# 1433                                             NaN
# ...                                              ...
# 19805                                            NaN
# 19806                                            NaN
# 19807                                            NaN
# 19808                                            NaN
# 19809                                            NaN
# 19810                                            NaN
# 19811                                            NaN
# 19812                                            NaN
# 19813                                            NaN
# 19814                                            NaN
# 19815                                            NaN
# 19816                                            NaN
# 19817                                            NaN
# 19818                                            NaN
# 19819                                            NaN
# 19820                                            NaN
# 19821                                            NaN
# 19822                                            NaN
# 19823                                            NaN
# 19824                                            NaN
# 19825                                            NaN
# 19826                                            NaN
# 19827                                            NaN
# 19828                                            NaN
# 19829                                            NaN
# 19830                                            NaN
# 19831                                            NaN
# 19832                                            NaN
# 19833                                            NaN
# 19834                                            NaN
#
#       Go:What other language(s) do you use?  \
# 1404                                    NaN
# 1405                                    NaN
# 1406                                    NaN
# 1407                                    NaN
# 1408                                    NaN
# 1409                                    NaN
# 1410                                     Go
# 1411                                    NaN
# 1412                                    NaN
# 1413                                    NaN
# 1414                                    NaN
# 1415                                    NaN
# 1416                                    NaN
# 1417                                    NaN
# 1418                                    NaN
# 1419                                     Go
# 1420                                    NaN
# 1421                                    NaN
# 1422                                    NaN
# 1423                                    NaN
# 1424                                    NaN
# 1425                                    NaN
# 1426                                    NaN
# 1427                                    NaN
# 1428                                    NaN
# 1429                                    NaN
# 1430                                    NaN
# 1431                                     Go
# 1432                                    NaN
# 1433                                    NaN
# ...                                     ...
# 19805                                   NaN
# 19806                                    Go
# 19807                                   NaN
# 19808                                   NaN
# 19809                                   NaN
# 19810                                   NaN
# 19811                                   NaN
# 19812                                   NaN
# 19813                                   NaN
# 19814                                   NaN
# 19815                                   NaN
# 19816                                   NaN
# 19817                                    Go
# 19818                                   NaN
# 19819                                   NaN
# 19820                                   NaN
# 19821                                   NaN
# 19822                                   NaN
# 19823                                   NaN
# 19824                                   NaN
# 19825                                   NaN
# 19826                                   NaN
# 19827                                    Go
# 19828                                   NaN
# 19829                                   NaN
# 19830                                   NaN
# 19831                                   NaN
# 19832                                   NaN
# 19833                                   NaN
# 19834                                   NaN
#
#                               ...                           \
# 1404                          ...
# 1405                          ...
# 1406                          ...
# 1407                          ...
# 1408                          ...
# 1409                          ...
# 1410                          ...
# 1411                          ...
# 1412                          ...
# 1413                          ...
# 1414                          ...
# 1415                          ...
# 1416                          ...
# 1417                          ...
# 1418                          ...
# 1419                          ...
# 1420                          ...
# 1421                          ...
# 1422                          ...
# 1423                          ...
# 1424                          ...
# 1425                          ...
# 1426                          ...
# 1427                          ...
# 1428                          ...
# 1429                          ...
# 1430                          ...
# 1431                          ...
# 1432                          ...
# 1433                          ...
# ...                           ...
# 19805                         ...
# 19806                         ...
# 19807                         ...
# 19808                         ...
# 19809                         ...
# 19810                         ...
# 19811                         ...
# 19812                         ...
# 19813                         ...
# 19814                         ...
# 19815                         ...
# 19816                         ...
# 19817                         ...
# 19818                         ...
# 19819                         ...
# 19820                         ...
# 19821                         ...
# 19822                         ...
# 19823                         ...
# 19824                         ...
# 19825                         ...
# 19826                         ...
# 19827                         ...
# 19828                         ...
# 19829                         ...
# 19830                         ...
# 19831                         ...
# 19832                         ...
# 19833                         ...
# 19834                         ...
#
#       R:What other language(s) do you use?  \
# 1404                                   NaN
# 1405                                   NaN
# 1406                                   NaN
# 1407                                   NaN
# 1408                                   NaN
# 1409                                     R
# 1410                                     R
# 1411                                   NaN
# 1412                                   NaN
# 1413                                   NaN
# 1414                                   NaN
# 1415                                   NaN
# 1416                                     R
# 1417                                   NaN
# 1418                                   NaN
# 1419                                   NaN
# 1420                                   NaN
# 1421                                   NaN
# 1422                                   NaN
# 1423                                   NaN
# 1424                                   NaN
# 1425                                   NaN
# 1426                                   NaN
# 1427                                   NaN
# 1428                                   NaN
# 1429                                   NaN
# 1430                                   NaN
# 1431                                   NaN
# 1432                                   NaN
# 1433                                   NaN
# ...                                    ...
# 19805                                    R
# 19806                                  NaN
# 19807                                  NaN
# 19808                                  NaN
# 19809                                  NaN
# 19810                                  NaN
# 19811                                  NaN
# 19812                                  NaN
# 19813                                  NaN
# 19814                                  NaN
# 19815                                  NaN
# 19816                                  NaN
# 19817                                  NaN
# 19818                                  NaN
# 19819                                  NaN
# 19820                                  NaN
# 19821                                  NaN
# 19822                                  NaN
# 19823                                  NaN
# 19824                                  NaN
# 19825                                  NaN
# 19826                                  NaN
# 19827                                  NaN
# 19828                                    R
# 19829                                  NaN
# 19830                                  NaN
# 19831                                  NaN
# 19832                                  NaN
# 19833                                    R
# 19834                                  NaN
#
#       Swift:What other language(s) do you use?  \
# 1404                                       NaN
# 1405                                       NaN
# 1406                                       NaN
# 1407                                       NaN
# 1408                                       NaN
# 1409                                       NaN
# 1410                                       NaN
# 1411                                       NaN
# 1412                                       NaN
# 1413                                       NaN
# 1414                                       NaN
# 1415                                       NaN
# 1416                                       NaN
# 1417                                       NaN
# 1418                                       NaN
# 1419                                       NaN
# 1420                                       NaN
# 1421                                       NaN
# 1422                                       NaN
# 1423                                       NaN
# 1424                                       NaN
# 1425                                       NaN
# 1426                                       NaN
# 1427                                       NaN
# 1428                                       NaN
# 1429                                       NaN
# 1430                                       NaN
# 1431                                       NaN
# 1432                                     Swift
# 1433                                       NaN
# ...                                        ...
# 19805                                      NaN
# 19806                                      NaN
# 19807                                      NaN
# 19808                                      NaN
# 19809                                      NaN
# 19810                                      NaN
# 19811                                      NaN
# 19812                                      NaN
# 19813                                      NaN
# 19814                                      NaN
# 19815                                      NaN
# 19816                                      NaN
# 19817                                      NaN
# 19818                                      NaN
# 19819                                      NaN
# 19820                                      NaN
# 19821                                      NaN
# 19822                                      NaN
# 19823                                      NaN
# 19824                                      NaN
# 19825                                      NaN
# 19826                                      NaN
# 19827                                      NaN
# 19828                                      NaN
# 19829                                      NaN
# 19830                                      NaN
# 19831                                      NaN
# 19832                                      NaN
# 19833                                      NaN
# 19834                                      NaN
#
#       Clojure:What other language(s) do you use?  \
# 1404                                         NaN
# 1405                                         NaN
# 1406                                         NaN
# 1407                                         NaN
# 1408                                     Clojure
# 1409                                         NaN
# 1410                                         NaN
# 1411                                         NaN
# 1412                                         NaN
# 1413                                         NaN
# 1414                                         NaN
# 1415                                         NaN
# 1416                                         NaN
# 1417                                         NaN
# 1418                                         NaN
# 1419                                         NaN
# 1420                                         NaN
# 1421                                         NaN
# 1422                                         NaN
# 1423                                         NaN
# 1424                                         NaN
# 1425                                         NaN
# 1426                                         NaN
# 1427                                         NaN
# 1428                                         NaN
# 1429                                         NaN
# 1430                                         NaN
# 1431                                         NaN
# 1432                                         NaN
# 1433                                         NaN
# ...                                          ...
# 19805                                        NaN
# 19806                                        NaN
# 19807                                        NaN
# 19808                                        NaN
# 19809                                        NaN
# 19810                                        NaN
# 19811                                        NaN
# 19812                                        NaN
# 19813                                        NaN
# 19814                                        NaN
# 19815                                        NaN
# 19816                                        NaN
# 19817                                        NaN
# 19818                                        NaN
# 19819                                        NaN
# 19820                                        NaN
# 19821                                        NaN
# 19822                                        NaN
# 19823                                        NaN
# 19824                                        NaN
# 19825                                        NaN
# 19826                                        NaN
# 19827                                        NaN
# 19828                                        NaN
# 19829                                        NaN
# 19830                                        NaN
# 19831                                        NaN
# 19832                                        NaN
# 19833                                        NaN
# 19834                                        NaN
#
#       Perl:What other language(s) do you use?  \
# 1404                                      NaN
# 1405                                      NaN
# 1406                                      NaN
# 1407                                      NaN
# 1408                                      NaN
# 1409                                      NaN
# 1410                                      NaN
# 1411                                      NaN
# 1412                                      NaN
# 1413                                      NaN
# 1414                                      NaN
# 1415                                      NaN
# 1416                                      NaN
# 1417                                      NaN
# 1418                                      NaN
# 1419                                      NaN
# 1420                                      NaN
# 1421                                      NaN
# 1422                                      NaN
# 1423                                      NaN
# 1424                                      NaN
# 1425                                      NaN
# 1426                                      NaN
# 1427                                      NaN
# 1428                                      NaN
# 1429                                      NaN
# 1430                                      NaN
# 1431                                      NaN
# 1432                                      NaN
# 1433                                      NaN
# ...                                       ...
# 19805                                     NaN
# 19806                                     NaN
# 19807                                     NaN
# 19808                                     NaN
# 19809                                     NaN
# 19810                                     NaN
# 19811                                     NaN
# 19812                                     NaN
# 19813                                     NaN
# 19814                                     NaN
# 19815                                     NaN
# 19816                                     NaN
# 19817                                     NaN
# 19818                                     NaN
# 19819                                     NaN
# 19820                                     NaN
# 19821                                     NaN
# 19822                                     NaN
# 19823                                     NaN
# 19824                                     NaN
# 19825                                     NaN
# 19826                                     NaN
# 19827                                     NaN
# 19828                                     NaN
# 19829                                     NaN
# 19830                                     NaN
# 19831                                     NaN
# 19832                                     NaN
# 19833                                     NaN
# 19834                                     NaN
#
#       Rust:What other language(s) do you use?  \
# 1404                                      NaN
# 1405                                      NaN
# 1406                                      NaN
# 1407                                      NaN
# 1408                                     Rust
# 1409                                      NaN
# 1410                                     Rust
# 1411                                      NaN
# 1412                                      NaN
# ...
# 1427                                        NaN
# 1428                                        NaN
# 1429                                        NaN
# 1430                                        NaN
# 1431                                        NaN
# 1432                                        NaN
# 1433                                        NaN
# ...                                         ...
# 19805                                       NaN
# 19806                                       NaN
# 19807                                       NaN
# 19808                                       NaN
# 19809                                       NaN
# 19810                                       NaN
# 19811                                       NaN
# 19812                                       NaN
# 19813                                       NaN
# 19814                                       NaN
# 19815                                       NaN
# 19816                                       NaN
# 19817                                       NaN
# 19818                                       NaN
# 19819                                       NaN
# 19820                                       NaN
# 19821                                       NaN
# 19822                                       NaN
# 19823                                       NaN
# 19824                                       NaN
# 19825                                       NaN
# 19826                                       NaN
# 19827                                       NaN
# 19828                                       NaN
# 19829                                       NaN
# 19830                                       NaN
# 19831                                       NaN
# 19832                                       NaN
# 19833                                       NaN
# 19834                                       NaN
#
#       TypeScript:What other language(s) do you use?  \
# 1404                                            NaN
# 1405                                            NaN
# 1406                                            NaN
# 1407                                            NaN
# 1408                                            NaN
# 1409                                            NaN
# 1410                                            NaN
# 1411                                            NaN
# 1412                                            NaN
# 1413                                            NaN
# 1414                                            NaN
# 1415                                            NaN
# 1416                                            NaN
# 1417                                            NaN
# 1418                                            NaN
# 1419                                     TypeScript
# 1420                                            NaN
# 1421                                            NaN
# 1422                                            NaN
# 1423                                            NaN
# 1424                                            NaN
# 1425                                            NaN
# 1426                                            NaN
# 1427                                            NaN
# 1428                                            NaN
# 1429                                            NaN
# 1430                                            NaN
# 1431                                            NaN
# 1432                                            NaN
# 1433                                            NaN
# ...                                             ...
# 19805                                           NaN
# 19806                                           NaN
# 19807                                           NaN
# 19808                                           NaN
# 19809                                           NaN
# 19810                                           NaN
# 19811                                           NaN
# 19812                                           NaN
# 19813                                           NaN
# 19814                                           NaN
# 19815                                           NaN
# 19816                                           NaN
# 19817                                           NaN
# 19818                                           NaN
# 19819                                           NaN
# 19820                                           NaN
# 19821                                           NaN
# 19822                                           NaN
# 19823                                           NaN
# 19824                                           NaN
# 19825                                           NaN
# 19826                                           NaN
# 19827                                           NaN
# 19828                                           NaN
# 19829                                           NaN
# 19830                                           NaN
# 19831                                           NaN
# 19832                                           NaN
# 19833                                           NaN
# 19834                                           NaN
#
#       CoffeeScript:What other language(s) do you use?  \
# 1404                                              NaN
# 1405                                              NaN
# 1406                                              NaN
# 1407                                              NaN
# 1408                                              NaN
# 1409                                              NaN
# 1410                                              NaN
# 1411                                              NaN
# 1412                                              NaN
# 1413                                              NaN
# 1414                                              NaN
# 1415                                              NaN
# 1416                                              NaN
# 1417                                              NaN
# 1418                                              NaN
# 1419                                              NaN
# 1420                                              NaN
# 1421                                              NaN
# 1422                                     CoffeeScript
# 1423                                              NaN
# 1424                                              NaN
# 1425                                              NaN
# 1426                                              NaN
# 1427                                              NaN
# 1428                                              NaN
# 1429                                              NaN
# 1430                                              NaN
# 1431                                              NaN
# 1432                                              NaN
# 1433                                              NaN
# ...                                               ...
# 19805                                             NaN
# 19806                                             NaN
# 19807                                             NaN
# 19808                                             NaN
# 19809                                             NaN
# 19810                                             NaN
# 19811                                             NaN
# 19812                                             NaN
# 19813                                             NaN
# 19814                                             NaN
# 19815                                             NaN
# 19816                                             NaN
# 19817                                             NaN
# 19818                                             NaN
# 19819                                             NaN
# 19820                                             NaN
# 19821                                             NaN
# 19822                                             NaN
# 19823                                             NaN
# 19824                                             NaN
# 19825                                             NaN
# 19826                                             NaN
# 19827                                             NaN
# 19828                                             NaN
# 19829                                             NaN
# 19830                                             NaN
# 19831                                             NaN
# 19832                                             NaN
# 19833                                             NaN
# 19834                                             NaN
#
#       HTML/CSS:What other language(s) do you use?  \
# 1404                                          NaN
# 1405                                     HTML/CSS
# 1406                                          NaN
# 1407                                          NaN
# 1408                                     HTML/CSS
# 1409                                          NaN
# 1410                                          NaN
# 1411                                          NaN
# 1412                                     HTML/CSS
# 1413                                          NaN
# 1414                                          NaN
# 1415                                     HTML/CSS
# 1416                                          NaN
# 1417                                          NaN
# 1418                                          NaN
# 1419                                     HTML/CSS
# 1420                                          NaN
# 1421                                     HTML/CSS
# 1422                                     HTML/CSS
# 1423                                     HTML/CSS
# 1424                                     HTML/CSS
# 1425                                     HTML/CSS
# 1426                                     HTML/CSS
# 1427                                     HTML/CSS
# 1428                                     HTML/CSS
# 1429                                          NaN
# 1430                                          NaN
# 1431                                          NaN
# 1432                                          NaN
# 1433                                          NaN
# ...                                           ...
# 19805                                    HTML/CSS
# 19806                                         NaN
# 19807                                    HTML/CSS
# 19808                                         NaN
# 19809                                         NaN
# 19810                                    HTML/CSS
# 19811                                    HTML/CSS
# 19812                                         NaN
# 19813                                         NaN
# 19814                                         NaN
# 19815                                    HTML/CSS
# 19816                                    HTML/CSS
# 19817                                    HTML/CSS
# 19818                                         NaN
# 19819                                    HTML/CSS
# 19820                                         NaN
# 19821                                         NaN
# 19822                                         NaN
# 19823                                         NaN
# 19824                                    HTML/CSS
# 19825                                    HTML/CSS
# 19826                                    HTML/CSS
# 19827                                         NaN
# 19828                                    HTML/CSS
# 19829                                         NaN
# 19830                                    HTML/CSS
# 19831                                    HTML/CSS
# 19832                                         NaN
# 19833                                         NaN
# 19834                                    HTML/CSS
#
#       Other - Write In::What other language(s) do you use?
# 1404                                                 NaN
# 1405                                                 NaN
# 1406                                                 NaN
# 1407                                   Other - Write In:
# 1408                                                 NaN
# 1409                                                 NaN
# 1410                                   Other - Write In:
# 1411                                                 NaN
# 1412                                                 NaN
# 1413                                                 NaN
# 1414                                                 NaN
# 1415                                                 NaN
# 1416                                                 NaN
# 1417                                                 NaN
# 1418                                                 NaN
# 1419                                   Other - Write In:
# 1420                                                 NaN
# 1421                                                 NaN
# 1422                                   Other - Write In:
# 1423                                   Other - Write In:
# 1424                                                 NaN
# 1425                                                 NaN
# 1426                                                 NaN
# 1427                                                 NaN
# 1428                                                 NaN
# 1429                                                 NaN
# 1430                                                 NaN
# 1431                                                 NaN
# 1432                                   Other - Write In:
# 1433                                                 NaN
# ...                                                  ...
# 19805                                                NaN
# 19806                                                NaN
# 19807                                  Other - Write In:
# 19808                                                NaN
# 19809                                                NaN
# 19810                                                NaN
# 19811                                                NaN
# 19812                                                NaN
# 19813                                                NaN
# 19814                                                NaN
# 19815                                                NaN
# 19816                                  Other - Write In:
# 19817                                                NaN
# 19818                                                NaN
# 19819                                  Other - Write In:
# 19820                                                NaN
# 19821                                  Other - Write In:
# 19822                                                NaN
# 19823                                  Other - Write In:
# 19824                                                NaN
# 19825                                                NaN
# 19826                                                NaN
# 19827                                                NaN
# 19828                                                NaN
# 19829                                                NaN
# 19830                                                NaN
# 19831                                                NaN
# 19832                                                NaN
# 19833                                                NaN
# 19834                                                NaN
#
# [18431 rows x 24 columns]

# %%
melted_observations = pd.melt(question_two, var_name='option', value_name='reply')

# melted_observations = melted_observations[ melted_observations.reply.dropna()]
melted_observations  = melted_observations.dropna()

print(melted_observations.option.value_counts())
print('-----------')
print(melted_observations.reply.value_counts())
# Out:
# JavaScript:What other language(s) do you use?           9233
# HTML/CSS:What other language(s) do you use?             8633
# Bash / Shell:What other language(s) do you use?         8245
# SQL:What other language(s) do you use?                  7451
# C/C++:What other language(s) do you use?                5757
# Java:What other language(s) do you use?                 4161
# PHP:What other language(s) do you use?                  2385
# C#:What other language(s) do you use?                   2077
# Other - Write In::What other language(s) do you use?    1900
# Go:What other language(s) do you use?                   1734
# R:What other language(s) do you use?                    1589
# TypeScript:What other language(s) do you use?           1385
# None:What other language(s) do you use?                 1015
# Ruby:What other language(s) do you use?                  800
# Visual Basic:What other language(s) do you use?          757
# Rust:What other language(s) do you use?                  741
# Perl:What other language(s) do you use?                  545
# Kotlin:What other language(s) do you use?                517
# Scala:What other language(s) do you use?                 509
# Swift:What other language(s) do you use?                 448
# Groovy:What other language(s) do you use?                307
# Objective-C:What other language(s) do you use?           254
# CoffeeScript:What other language(s) do you use?          151
# Clojure:What other language(s) do you use?               145
# Name: option, dtype: int64
# -----------
# JavaScript           9233
# HTML/CSS             8633
# Bash / Shell         8245
# SQL                  7451
# C/C++                5757
# Java                 4161
# PHP                  2385
# C#                   2077
# Other - Write In:    1900
# Go                   1734
# R                    1589
# TypeScript           1385
# None                 1015
# Ruby                  800
# Visual Basic          757
# Rust                  741
# Perl                  545
# Kotlin                517
# Scala                 509
# Swift                 448
# Groovy                307
# Objective-C           254
# CoffeeScript          151
# Clojure               145
# Name: reply, dtype: int64

# %%
lamda_func = lambda row: 'What other language(s) do you use?'

melted_observations.option = melted_observations.apply(lamda_func,axis=1)

melted_observations.reply = melted_observations.reply.astype('category')
melted_observations.option = melted_observations.option.astype('category')
melted_observations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60739 entries, 26 to 442332
# Data columns (total 2 columns):
# option    60739 non-null category
# reply     60739 non-null category
# dtypes: category(2)
# memory usage: 594.1 KB

# %%
# converting the option to the question title

melted_observations.head()
# Out:
#                                  option reply
# 26   What other language(s) do you use?  None
# 64   What other language(s) do you use?  None
# 159  What other language(s) do you use?  None
# 206  What other language(s) do you use?  None
# 209  What other language(s) do you use?  None

# %%
sheet_ready_question_two = melted_observations.pivot(columns='option' , values='reply')

# %%
sheet_ready_question_two.describe()
sheet_ready_question_two.iloc[:, 0] .value_counts()
# Out:
# JavaScript           9233
# HTML/CSS             8633
# Bash / Shell         8245
# SQL                  7451
# C/C++                5757
# Java                 4161
# PHP                  2385
# C#                   2077
# Other - Write In:    1900
# Go                   1734
# R                    1589
# TypeScript           1385
# None                 1015
# Ruby                  800
# Visual Basic          757
# Rust                  741
# Perl                  545
# Kotlin                517
# Scala                 509
# Swift                 448
# Groovy                307
# Objective-C           254
# CoffeeScript          151
# Clojure               145
# Name: What other language(s) do you use?, dtype: int64

# %% [markdown]
# We have successfully prepared the question two data for analysis and stored it in the `sheet_ready_question_two` variable. Next is to process question three
#
#
# Next let us process the next question
#
# ## Question 3
#
# > For what purposes do you mainly use Python?
#
# The above is single choice question with the options
# - For work
# - For personal education
# - Both for work and personal

# %%
question_three = PYTHON_OBSERVATIONS_DF.iloc[:, [26]]
question_three.head()
# Out:
#      For what purposes do you mainly use Python?
# 1404                  Both for work and personal
# 1405                  Both for work and personal
# 1406                                    For work
# 1407                  Both for work and personal
# 1408                  Both for work and personal

# %%
question_three.iloc[:, 0].value_counts()
# Out:
# Both for work and personal                     10987
# For personal, educational  or side projects     3852
# For work                                        3592
# Name: For what purposes do you mainly use Python?, dtype: int64

# %% [markdown]
# The data is in the exact shape and structure as we want it. Thus we can say that this data is ready to be exported to the excel sheets

# %%
sheet_ready_question_three = question_three

# %% [markdown]
# ### Question 4
#
# This is a multi-choice question that has the same structure like question one. Each option is stored as a column. We would like to do the exact same cleaning as before.
#
# Looking at this right now, we see that there is a need to abstract the steps of cleanning the data into functions. Thus, making it easy to re-shape similar data
#
# What we are going to do here, is to create functions that handle the extraction of multi-choice question

# %%
# Let us first get the dataframe for the questions

question_four_df = PYTHON_OBSERVATIONS_DF.iloc[:, 27:43]

question_four_df.head()
# Out:
#      Educational purposes:What do you use Python for?  \
# 1404                                              NaN
# 1405                                              NaN
# 1406                             Educational purposes
# 1407                                              NaN
# 1408                                              NaN
#
#      Data analysis:What do you use Python for?  \
# 1404                             Data analysis
# 1405                             Data analysis
# 1406                                       NaN
# 1407                             Data analysis
# 1408                             Data analysis
#
#      DevOps / System administration / Writing automation scripts:What do you use Python for?  \
# 1404  DevOps / System administration / Writing autom...
# 1405                                                NaN
# 1406  DevOps / System administration / Writing autom...
# 1407  DevOps / System administration / Writing autom...
# 1408  DevOps / System administration / Writing autom...
#
#      Software testing / Writing automated tests:What do you use Python for?  \
# 1404         Software testing / Writing automated tests
# 1405                                                NaN
# 1406                                                NaN
# 1407         Software testing / Writing automated tests
# 1408         Software testing / Writing automated tests
#
#      Software prototyping:What do you use Python for?  \
# 1404                                              NaN
# 1405                                              NaN
# 1406                                              NaN
# 1407                             Software prototyping
# 1408                                              NaN
#
#      Web development:What do you use Python for?  \
# 1404                                         NaN
# 1405                             Web development
# 1406                                         NaN
# 1407                             Web development
# 1408                             Web development
#
#      Machine learning:What do you use Python for?  \
# 1404                             Machine learning
# 1405                             Machine learning
# 1406                                          NaN
# 1407                                          NaN
# 1408                             Machine learning
#
#      Mobile development:What do you use Python for?  \
# 1404                                            NaN
# 1405                                            NaN
# 1406                                            NaN
# 1407                                            NaN
# 1408                                            NaN
#
#      Desktop development:What do you use Python for?  \
# 1404                                             NaN
# 1405                                             NaN
# 1406                                             NaN
# 1407                             Desktop development
# 1408                                             NaN
#
#      Computer graphics:What do you use Python for?  \
# 1404                                           NaN
# 1405                                           NaN
# 1406                                           NaN
# 1407                                           NaN
# 1408                                           NaN
#
#      Network programming:What do you use Python for?  \
# 1404                                             NaN
# 1405                                             NaN
# 1406                             Network programming
# 1407                             Network programming
# 1408                             Network programming
#
#      Game development:What do you use Python for?  \
# 1404                                          NaN
# 1405                                          NaN
# 1406                                          NaN
# 1407                                          NaN
# 1408                                          NaN
#
#      Multimedia applications development:What do you use Python for?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Embedded development:What do you use Python for?  \
# 1404                                              NaN
# 1405                                              NaN
# 1406                                              NaN
# 1407                                              NaN
# 1408                                              NaN
#
#      Programming of web parsers / scrapers / crawlers:What do you use Python for?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407   Programming of web parsers / scrapers / crawlers
# 1408   Programming of web parsers / scrapers / crawlers
#
#      Other - Write In::What do you use Python for?
# 1404                                           NaN
# 1405                                           NaN
# 1406                                           NaN
# 1407                                           NaN
# 1408                                           NaN

# %%
def reshape_data(dataframe, question_asked, var_name='question', value_name='answer_chosen', fillna_with_str='', dropna=True ):
    melted_observations = pd.melt(dataframe, var_name=var_name, value_name=value_name)

    # melted_observations = melted_observations[ melted_observations.reply.dropna()]
    if dropna:
        melted_observations  = melted_observations.dropna()
    else:
        melted_observations  = melted_observations.fillna(fillna_with_str)

    lamda_func = lambda row: question_asked

    melted_observations[var_name] = melted_observations.apply(lamda_func,axis=1)
    
    pivoted_data = melted_observations.pivot(columns=var_name , values=value_name)
    return pivoted_data

# %%
sheet_ready_question_four = reshape_data(question_four_df, question_asked='What do you use Python for?')
sheet_ready_question_four.head()
# Out:
# question What do you use Python for?
# 2               Educational purposes
# 5               Educational purposes
# 6               Educational purposes
# 7               Educational purposes
# 8               Educational purposes

# %%
sheet_ready_question_four.iloc[:, 0].value_counts(dropna=False)
# Out:
# Data analysis                                                  10615
# Web development                                                 9656
# DevOps / System administration / Writing automation scripts     7853
# Machine learning                                                7074
# Programming of web parsers / scrapers / crawlers                6799
# Software testing / Writing automated tests                      5859
# Educational purposes                                            5108
# Software prototyping                                            4955
# Network programming                                             3755
# Desktop development                                             3442
# Computer graphics                                               1694
# Embedded development                                            1482
# Other - Write In:                                               1312
# Game development                                                1186
# Mobile development                                               836
# Multimedia applications development                              639
# Name: What do you use Python for?, dtype: int64

# %%
sheet_ready_question_four.iloc[:, 0].describe()
# Out:
# count             72265
# unique               16
# top       Data analysis
# freq              10615
# Name: What do you use Python for?, dtype: object

# %%
sheet_ready_question_four.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72265 entries, 2 to 294882
# Data columns (total 1 columns):
# What do you use Python for?    72265 non-null object
# dtypes: object(1)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Pipped question from question 4
#
#
# The following questions(**question 5 and 6**) were piped for question 4:
#
# **Question 5**
# > To what extent are you involved in the following activities?
#
# The answer to this question has the following properties:
# - all the option from `question 4`*(what do you use python for?)* are repeated as columns and the values are either primary activity, secondary activity or hobby
# - the options the user answered from `question 4` are all contained in this question
#
# **Question 6**
# > What do you use Python for most?
#
# This value of this question is `Nan` if the user selected only one answer from `question 4`. Thus, we can assume that the answer to this question when the value is `Nan` is the one answer the user selected
#
# **Question 7**
# > Do you consider yourself as a Data-Scientist?
#
# This question is displayed if the user selects "Data analysis" or "Machine learning" as the answer to question_four. Thus, we can replace the `Nan` with `I do neither data science nor machine learning`

# %%
question_five = PYTHON_OBSERVATIONS_DF.iloc[:, 43:59]
question_five.head()
# Out:
#      Educational purposes:To what extent are you involvedin the following activities?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                              hobby
# 1407                                                NaN
# 1408                                                NaN
#
#      Data analysis:To what extent are you involvedin the following activities?  \
# 1404                                   primary activity
# 1405                                   primary activity
# 1406                                                NaN
# 1407                                 secondary activity
# 1408                                   primary activity
#
#      DevOps / System administration / Writing automation scripts:To what extent are you involvedin the following activities?  \
# 1404                                 secondary activity
# 1405                                                NaN
# 1406                                   primary activity
# 1407                                   primary activity
# 1408                                 secondary activity
#
#      Software testing / Writing automated tests:To what extent are you involvedin the following activities?  \
# 1404                                 secondary activity
# 1405                                                NaN
# 1406                                                NaN
# 1407                                 secondary activity
# 1408                                 secondary activity
#
#      Software prototyping:To what extent are you involvedin the following activities?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                              hobby
# 1408                                                NaN
#
#      Web development:To what extent are you involvedin the following activities?  \
# 1404                                                NaN
# 1405                                   primary activity
# 1406                                                NaN
# 1407                                 secondary activity
# 1408                                   primary activity
#
#      Machine learning:To what extent are you involvedin the following activities?  \
# 1404                                              hobby
# 1405                                   primary activity
# 1406                                                NaN
# 1407                                                NaN
# 1408                                 secondary activity
#
#      Mobile development:To what extent are you involvedin the following activities?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Desktop development:To what extent are you involvedin the following activities?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                 secondary activity
# 1408                                                NaN
#
#      Computer graphics:To what extent are you involvedin the following activities?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Network programming:To what extent are you involvedin the following activities?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                   primary activity
# 1407                                   primary activity
# 1408                                 secondary activity
#
#      Game development:To what extent are you involvedin the following activities?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Multimedia applications development:To what extent are you involvedin the following activities?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Embedded development:To what extent are you involvedin the following activities?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Programming of web parsers / scrapers / crawlers:To what extent are you involvedin the following activities?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                 secondary activity
# 1408                                 secondary activity
#
#      Other - Write In::To what extent are you involvedin the following activities?
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN

# %%
sheet_ready_question_five = reshape_data(question_five, question_asked='To what extent are you involvedin the following activities?')
sheet_ready_question_five.head()
# Out:
# question To what extent are you involvedin the following activities?
# 2                                                     hobby
# 5                                          primary activity
# 6                                          primary activity
# 7                                          primary activity
# 8                                        secondary activity

# %%
sheet_ready_question_four.shape
# Out:
# (72265, 1)

# %%
sheet_ready_question_five.shape
# Out:
# (72265, 1)

# %%
sheet_ready_question_five = pd.merge(sheet_ready_question_four, sheet_ready_question_five,left_index=True, right_index=True)

# %%
print(sheet_ready_question_five.shape)
sheet_ready_question_five.head()
# Out:
# (72265, 2)
# question What do you use Python for?  \
# 2               Educational purposes
# 5               Educational purposes
# 6               Educational purposes
# 7               Educational purposes
# 8               Educational purposes
#
# question To what extent are you involvedin the following activities?
# 2                                                     hobby
# 5                                          primary activity
# 6                                          primary activity
# 7                                          primary activity
# 8                                        secondary activity

# %%
question_six = PYTHON_OBSERVATIONS_DF.iloc[:, [59]]
question_six.head()
print(question_six.shape)
question_six = pd.merge(question_four_df, question_six, left_index=True, right_index=True)
# Out:
# (18431, 1)

# %%
print(question_six.iloc[:, -1].value_counts(dropna=False))
print(question_six.shape)
question_six.iloc[:, [-1]].head()
# Out:
# Web development                                                4364
# Data analysis                                                  2800
# NaN                                                            2184
# Machine learning                                               1785
# DevOps / System administration / Writing automation scripts    1738
# Educational purposes                                           1191
# Other - Write In:                                               872
# Desktop development                                             685
# Software prototyping                                            630
# Programming of web parsers / scrapers / crawlers                595
# Software testing / Writing automated tests                      560
# Network programming                                             457
# Embedded development                                            198
# Game development                                                158
# Computer graphics                                                94
# Multimedia applications development                              70
# Mobile development                                               50
# Name: What do you use Python for the most?, dtype: int64
# (18431, 17)
#                    What do you use Python for the most?
# 1404                                      Data analysis
# 1405                                    Web development
# 1406  DevOps / System administration / Writing autom...
# 1407                               Software prototyping
# 1408                                    Web development

# %%
def change_all_nans_to_main_use(row):
    """Replaces the nan values
    
    Replaces the nan values in the column 'What do you use Python for the most?'
    with the answer to the question 'What do you use Python for?'
    
    """
    users_most_python_use_case = row[-1]
    if isinstance(users_most_python_use_case, float) and  math.isnan(users_most_python_use_case) :

        primary_use_case = next(item for item in row.values if isinstance(item, str))
        row[-1]= primary_use_case
        
    return row

question_six_with_no_nans  = question_six.apply(change_all_nans_to_main_use,axis=1)
question_six_with_no_nans.iloc[:, -1].value_counts(dropna=False)

question_six_with_no_nans = question_six_with_no_nans.iloc[:,[ -1]]
question_six_with_no_nans.head()
# Out:
#                    What do you use Python for the most?
# 1404                                      Data analysis
# 1405                                    Web development
# 1406  DevOps / System administration / Writing autom...
# 1407                               Software prototyping
# 1408                                    Web development

# %%
question_six_with_no_nans.iloc[:,0].value_counts(dropna=False)
# Out:
# Web development                                                5072
# Data analysis                                                  3136
# DevOps / System administration / Writing automation scripts    1950
# Machine learning                                               1923
# Educational purposes                                           1496
# Other - Write In:                                               876
# Desktop development                                             780
# Software prototyping                                            650
# Software testing / Writing automated tests                      650
# Programming of web parsers / scrapers / crawlers                637
# Network programming                                             501
# Embedded development                                            233
# Game development                                                211
# Computer graphics                                               169
# Multimedia applications development                              81
# Mobile development                                               66
# Name: What do you use Python for the most?, dtype: int64

# %%
sheet_ready_question_six = question_six_with_no_nans

# %%
question_seven = PYTHON_OBSERVATIONS_DF.iloc[:, [60]]
question_seven.head()
# Out:
#      Do you consider yourself as a Data-Scientist?
# 1404                                            No
# 1405                                            No
# 1406                                           NaN
# 1407                                            No
# 1408                                            No

# %%
question_seven.iloc[:, 0].value_counts(dropna=False)
# Out:
# No                   7509
# NaN                  6582
# Yes                  3606
# Other – Write In:     734
# Name: Do you consider yourself as a Data-Scientist?, dtype: int64

# %%
sheet_ready_question_seven = \
    question_seven.fillna('I do neither data science nor machine learning')
sheet_ready_question_seven.iloc[:, 0].value_counts(dropna=False)
# Out:
# No                                                7509
# I do neither data science nor machine learning    6582
# Yes                                               3606
# Other – Write In:                                  734
# Name: Do you consider yourself as a Data-Scientist?, dtype: int64

# %% [markdown]
# #### Question 8
#
# > Which version of Python do you use the most?*
#
# There are only two possible answers to this question namely:
# - Python 2
# - Python 3

# %%
# Extracting the answers to question 8 and storing it in the variable question_eight
question_eight = PYTHON_OBSERVATIONS_DF.iloc[:, [61]]
print(question_eight.iloc[:, 0].value_counts(dropna=False))
question_eight.head()
# Out:
# Python 3    15446
# Python 2     2985
# Name: Which version of Python do you use the most?, dtype: int64
#      Which version of Python do you use the most?
# 1404                                     Python 3
# 1405                                     Python 3
# 1406                                     Python 3
# 1407                                     Python 3
# 1408                                     Python 3

# %% [markdown]
# The data above is as clean as can be as there are no Nan values

# %%
# Since the data is sheet ready we store it in sheet_ready_question_eight variable
sheet_ready_question_eight = question_eight
sheet_ready_question_eight.shape
# Out:
# (18431, 1)

# %% [markdown]
# #### Pipped question from question 8
#
# The next two questions are dependent on the answer of question 8
#
# **Quesiton 9**
# >Which version of Python 2 do you use the most?*
#
# The above question is displayed when the user selects `python 2` in  question 8
#
# **Quesiton 10**
# >Which version of Python 3 do you use the most?*
#
# The above question is displayed when the user selects `python 3` in  question 8
#
#
# Nan logic
# ---
#
# When the question is not displayed to the user,  then `Nan` is put as the value. I think we can just dropna for both questions

# %%
# Extracting the answers to question 9 and storing it in the variable question_nine
question_nine = PYTHON_OBSERVATIONS_DF.iloc[:, [62]]
print(question_nine.iloc[:, 0].value_counts(dropna=False))
question_nine.head()
# Out:
# NaN           15605
# Python 2.7     2630
# Python 2.6       65
# Python 2.0       46
# Python 2.4       20
# Python 2.1       18
# Python 2.5       17
# Python 2.3       16
# Python 2.2       14
# Name: Which version of Python 2 do you use the most?, dtype: int64
#      Which version of Python 2 do you use the most?
# 1404                                            NaN
# 1405                                            NaN
# 1406                                            NaN
# 1407                                            NaN
# 1408                                            NaN

# %%
# Extracting the answers to question 10 and storing it in the variable question_ten
question_ten = PYTHON_OBSERVATIONS_DF.iloc[:, [63]]
print(question_ten.iloc[:, 0].value_counts(dropna=False))
question_ten.head()
# Out:
# Python 3.6    7812
# Python 3.7    4277
# NaN           4089
# Python 3.5    1550
# Python 3.4     394
# Python 3.0      94
# Python 3.2      75
# Python 3.1      72
# Python 3.3      68
# Name: Which version of Python 3 do you use the most?, dtype: int64
#      Which version of Python 3 do you use the most?
# 1404                                     Python 3.6
# 1405                                     Python 3.7
# 1406                                     Python 3.6
# 1407                                     Python 3.6
# 1408                                     Python 3.5

# %%
sheet_ready_question_nine = question_nine.dropna()
sheet_ready_question_ten = question_ten.dropna()

print(sheet_ready_question_nine.iloc[:, 0].value_counts())
print('-----')
print(sheet_ready_question_ten.iloc[:, 0].value_counts())
# Out:
# Python 2.7    2630
# Python 2.6      65
# Python 2.0      46
# Python 2.4      20
# Python 2.1      18
# Python 2.5      17
# Python 2.3      16
# Python 2.2      14
# Name: Which version of Python 2 do you use the most?, dtype: int64
# -----
# Python 3.6    7812
# Python 3.7    4277
# Python 3.5    1550
# Python 3.4     394
# Python 3.0      94
# Python 3.2      75
# Python 3.1      72
# Python 3.3      68
# Name: Which version of Python 3 do you use the most?, dtype: int64

# %% [markdown]
# #### Question 11
#
# > What do you typically use to upgrade your Python version?
#
# The above is a multi-choice question whose options are stored in column index 64 to 77. We would process this using the `reshape_data` function that reshapes multi-choice questions

# %%
question_eleven = PYTHON_OBSERVATIONS_DF.iloc[:, 64:78]
print(question_eleven.shape)
question_eleven.head()
# Out:
# (18431, 14)
#      I dont update:What do you typically use to upgrade your Python version?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Somebody else manages Python updates for me:What do you typically use to upgrade your Python version?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Python.org:What do you typically use to upgrade your Python version?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                         Python.org
# 1407                                         Python.org
# 1408                                                NaN
#
#      Build from source:What do you typically use to upgrade your Python version?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Automatic upgrade via cloud provider:What do you typically use to upgrade your Python version?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Enthought:What do you typically use to upgrade your Python version?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Anaconda:What do you typically use to upgrade your Python version?  \
# 1404                                           Anaconda
# 1405                                           Anaconda
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      ActivePython:What do you typically use to upgrade your Python version?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Intel Distribution for Python:What do you typically use to upgrade your Python version?  \
# 1404                                                NaN
# 1405                      Intel Distribution for Python
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      OS-provided Python (via apt-get, yum, homebrew, etc.):What do you typically use to upgrade your Python version?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407  OS-provided Python (via apt-get, yum, homebrew...
# 1408  OS-provided Python (via apt-get, yum, homebrew...
#
#      pyenv:What do you typically use to upgrade your Python version?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      pythonz:What do you typically use to upgrade your Python version?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      I use Docker containers:What do you typically use to upgrade your Python version?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                            I use Docker containers
#
#      Other  Write In::What do you typically use to upgrade your Python version?
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN

# %%
sheet_ready_question_eleven = \
reshape_data(question_eleven, question_asked='What do you typically use to upgrade your Python version?')

print(sheet_ready_question_eleven.shape)
sheet_ready_question_eleven.iloc[:, 0].value_counts()
# Out:
# (27697, 1)
# OS-provided Python (via apt-get, yum, homebrew, etc.)    6912
# Python.org                                               6128
# Anaconda                                                 4054
# I use Docker containers                                  2788
# pyenv                                                    2728
# I don’t update                                           1539
# Build from source                                        1297
# Somebody else manages Python updates for me               854
# Other – Write In:                                         606
# Automatic upgrade via cloud provider                      348
# Intel Distribution for Python                             171
# ActivePython                                              151
# pythonz                                                    69
# Enthought                                                  52
# Name: What do you typically use to upgrade your Python version?, dtype: int64

# %% [markdown]
# #### Question 12
#
# > Do you use any of the following tools to isolate Python environments, if any?
#
# The above is a multi-choice question whose options are stored in column index 78 to 83. We do exactly what we did for question 11

# %%
question_twelve = PYTHON_OBSERVATIONS_DF.iloc[:, 78:84]
print(question_twelve.shape)
question_twelve.head()
# Out:
# (18431, 6)
#      None:Do you use any of the following tools to isolate Python environments, if any?  \
# 1404                                               None
# 1405                                                NaN
# 1406                                               None
# 1407                                                NaN
# 1408                                                NaN
#
#      Virtualenv / pipenv:Do you use any of the following tools to isolate Python environments, if any?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                Virtualenv / pipenv
# 1408                                Virtualenv / pipenv
#
#      Conda:Do you use any of the following tools to isolate Python environments, if any?  \
# 1404                                                NaN
# 1405                                              Conda
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Docker:Do you use any of the following tools to isolate Python environments, if any?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                             Docker
#
#      Vagrant  / virtual machines:Do you use any of the following tools to isolate Python environments, if any?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Other  Write In::Do you use any of the following tools to isolate Python environments, if any?
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN

# %%
question_12_str = 'Do you use any of the following tools to isolate Python environments, if any?'
sheet_ready_question_twelve = \
reshape_data(question_twelve, question_asked=question_12_str)

print(sheet_ready_question_twelve.shape)
sheet_ready_question_twelve.iloc[:, 0].value_counts()
# Out:
# (27636, 1)
# Virtualenv / pipenv            11729
# Docker                          5787
# Conda                           4084
# None                            3800
# Vagrant  / virtual machines     1676
# Other – Write In:                560
# Name: Do you use any of the following tools to isolate Python environments, if any?, dtype: int64

# %% [markdown]
# #### Question 13
#
# > What web frameworks / libraries do you use in addition to Python?
#
# Multi question with columns spanning index 83 to 95. Similar processing

# %%
# Extracting the data
question_13_str = 'What web frameworks / libraries do you use in addition to Python?'

question_thirteen = PYTHON_OBSERVATIONS_DF.iloc[:, 84:96]
print(question_thirteen.shape)
question_thirteen.head()
# Out:
# (18431, 12)
#      None:What web frameworks / libraries do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                               None
# 1407                                                NaN
# 1408                                                NaN
#
#      Django:What web frameworks / libraries do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                             Django
# 1406                                                NaN
# 1407                                             Django
# 1408                                             Django
#
#      TurboGears:What web frameworks / libraries do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      web2py:What web frameworks / libraries do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Bottle:What web frameworks / libraries do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      CherryPy:What web frameworks / libraries do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Flask:What web frameworks / libraries do you use in addition to Python?  \
# 1404                                             Flask
# 1405                                                NaN
# 1406                                                NaN
# 1407                                             Flask
# 1408                                             Flask
#
#      Hug:What web frameworks / libraries do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Pyramid:What web frameworks / libraries do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Tornado:What web frameworks / libraries do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                            Tornado
#
#      Falcon:What web frameworks / libraries do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Other  Write In::What web frameworks / libraries do you use in addition to Python?
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN

# %%
sheet_ready_question_thirteen = \
reshape_data(question_thirteen, question_asked=question_13_str)

print(sheet_ready_question_thirteen.shape)
sheet_ready_question_thirteen.iloc[:, 0].value_counts(dropna=False)
# Out:
# (54890, 1)
# Virtualenv / pipenv            11729
# Flask                           8615
# None                            8473
# Django                          8354
# Docker                          5787
# Conda                           4084
# Other – Write In:               1732
# Vagrant  / virtual machines     1676
# Tornado                         1080
# Pyramid                          720
# web2py                           693
# Bottle                           684
# CherryPy                         543
# Falcon                           456
# Hug                              159
# TurboGears                       105
# Name: What web frameworks / libraries do you use in addition to Python?, dtype: int64

# %% [markdown]
# #### Question 14
#
# > What data science framework(s) do you use in addition to Python?
#
# Multi question with columns spanning index 96 to 108. Similar processing

# %%
question_14_str = 'What data science framework(s) do you use in addition to Python?'
question_fourteen = PYTHON_OBSERVATIONS_DF.iloc[:, 96:109]
print(question_fourteen.shape)
question_fourteen.head()
# Out:
# (18431, 13)
#      None:What data science framework(s) do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                               None
# 1407                                                NaN
# 1408                                                NaN
#
#      NumPy:What data science framework(s) do you use in addition to Python?  \
# 1404                                              NumPy
# 1405                                                NaN
# 1406                                                NaN
# 1407                                              NumPy
# 1408                                              NumPy
#
#      SciPy:What data science framework(s) do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                              SciPy
# 1408                                                NaN
#
#      Pandas:What data science framework(s) do you use in addition to Python?  \
# 1404                                             Pandas
# 1405                                             Pandas
# 1406                                                NaN
# 1407                                                NaN
# 1408                                             Pandas
#
#      Matplotlib:What data science framework(s) do you use in addition to Python?  \
# 1404                                         Matplotlib
# 1405                                         Matplotlib
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Seaborn:What data science framework(s) do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      SciKit-Learn:What data science framework(s) do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                       SciKit-Learn
#
#      Keras:What data science framework(s) do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                              Keras
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      TensorFlow:What data science framework(s) do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                         TensorFlow
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Theano:What data science framework(s) do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      NLTK:What data science framework(s) do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Gensim:What data science framework(s) do you use in addition to Python?  \
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN
#
#      Other - Write In::What data science framework(s) do you use in addition to Python?
# 1404                                                NaN
# 1405                                                NaN
# 1406                                                NaN
# 1407                                                NaN
# 1408                                                NaN

# %%
sheet_ready_question_fourteen = \
reshape_data(question_fourteen, question_asked=question_14_str)

print(sheet_ready_question_fourteen.shape)
sheet_ready_question_fourteen.iloc[:, 0].value_counts(dropna=False)
# Out:
# (61707, 1)
# NumPy                11384
# Pandas                9314
# Matplotlib            8434
# SciPy                 6989
# SciKit-Learn          5787
# None                  5018
# TensorFlow            4653
# Keras                 2776
# Seaborn               2713
# NLTK                  2413
# Other - Write In:      909
# Gensim                 760
# Theano                 557
# Name: What data science framework(s) do you use in addition to Python?, dtype: int64

# %% [markdown]
# The last few processing seemed similar. Although most of the work was done in the function `reshape_data`, it turns out that there are some repetitions.
#
# I would like to spend some time creating functions that automate these repetitions

# %%
def reshape_and_show_info(question_asked, start_index, end_index):
    untidy_question_df = PYTHON_OBSERVATIONS_DF.iloc[:, start_index:end_index]
    print('---Initial Shape---')
    print(question_fourteen.shape)
    reshaped_df = \
    reshape_data(untidy_question_df, question_asked=question_asked)
    
    print('---Shape after reshaping---')
    print(reshaped_df.shape)
    print(reshaped_df.iloc[:, 0].value_counts(dropna=False))
    return reshaped_df

# %% [markdown]
# Subsequently, I would simply cann the function `reshape_and_show_info` for multi-choice questions

# %% [markdown]
# #### Question 15
#
# > Which of the following frameworks / libraries do you use in addition to Python?
#
# Multi question with columns spanning index 109 to 123. Would be processed using the `reshape_and_show_info `

# %%
question_15_str = 'Which of the following frameworks / libraries do you use in addition to Python?'

sheet_ready_question_fifteen = reshape_and_show_info( question_15_str, 109, 124)
sheet_ready_question_fifteen
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (43581, 1)
# Requests             9834
# Pillow               5430
# Scrapy               3462
# Asyncio              3311
# Tkinter              3303
# None                 3285
# PyQT                 2985
# Six                  2620
# aiohttp              1948
# Pygame               1943
# Other – Write In:    1364
# wxPython             1131
# Twisted              1125
# Kivy                 1043
# PyGTK                 797
# Name: Which of the following frameworks / libraries do you use in addition to Python?, dtype: int64
# question Which of the following frameworks / libraries do you use in addition to Python?
# 0                                                      None
# 12                                                     None
# 20                                                     None
# 25                                                     None
# 29                                                     None
# 44                                                     None
# 45                                                     None
# 50                                                     None
# 67                                                     None
# 93                                                     None
# 102                                                    None
# 104                                                    None
# 107                                                    None
# 117                                                    None
# 126                                                    None
# 133                                                    None
# 137                                                    None
# 141                                                    None
# 154                                                    None
# 166                                                    None
# 169                                                    None
# 171                                                    None
# 183                                                    None
# 187                                                    None
# 199                                                    None
# 224                                                    None
# 225                                                    None
# 230                                                    None
# 234                                                    None
# 236                                                    None
# ...                                                     ...
# 276029                                    Other – Write In:
# 276030                                    Other – Write In:
# 276032                                    Other – Write In:
# 276034                                    Other – Write In:
# 276044                                    Other – Write In:
# 276078                                    Other – Write In:
# 276093                                    Other – Write In:
# 276111                                    Other – Write In:
# 276113                                    Other – Write In:
# 276122                                    Other – Write In:
# 276126                                    Other – Write In:
# 276146                                    Other – Write In:
# 276163                                    Other – Write In:
# 276172                                    Other – Write In:
# 276198                                    Other – Write In:
# 276201                                    Other – Write In:
# 276232                                    Other – Write In:
# 276240                                    Other – Write In:
# 276243                                    Other – Write In:
# 276248                                    Other – Write In:
# 276253                                    Other – Write In:
# 276265                                    Other – Write In:
# 276278                                    Other – Write In:
# 276289                                    Other – Write In:
# 276303                                    Other – Write In:
# 276332                                    Other – Write In:
# 276346                                    Other – Write In:
# 276347                                    Other – Write In:
# 276356                                    Other – Write In:
# 276383                                    Other – Write In:
#
# [43581 rows x 1 columns]

# %% [markdown]
# #### Question 16
#
# > Which of the following cloud platforms do you use?
#
# Multi question with columns spanning index 124 to 135. Similar processing

# %%
question_str ='Which of the following cloud platforms do you use?'
sheet_ready_question_sixteen = reshape_and_show_info( question_str, 124, 136)
sheet_ready_question_sixteen
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (28938, 1)
# AWS                      6679
# None                     6354
# Google Cloud Platform    3623
# DigitalOcean             3133
# Heroku                   2603
# Microsoft Azure          1845
# PythonAnywhere           1561
# Other – Write In:        1008
# OpenStack                 812
# Linode                    723
# OpenShift                 396
# Rackspace                 201
# Name: Which of the following cloud platforms do you use?, dtype: int64
# question Which of the following cloud platforms do you use?
# 2                                                      None
# 4                                                      None
# 7                                                      None
# 8                                                      None
# 12                                                     None
# 15                                                     None
# 23                                                     None
# 25                                                     None
# 26                                                     None
# 27                                                     None
# 28                                                     None
# 29                                                     None
# 31                                                     None
# 37                                                     None
# 49                                                     None
# 51                                                     None
# 53                                                     None
# 54                                                     None
# 55                                                     None
# 58                                                     None
# 62                                                     None
# 67                                                     None
# 68                                                     None
# 80                                                     None
# 83                                                     None
# 87                                                     None
# 94                                                     None
# 102                                                    None
# 104                                                    None
# 105                                                    None
# ...                                                     ...
# 220292                                    Other – Write In:
# 220293                                    Other – Write In:
# 220299                                    Other – Write In:
# 220306                                    Other – Write In:
# 220326                                    Other – Write In:
# 220347                                    Other – Write In:
# 220373                                    Other – Write In:
# 220378                                    Other – Write In:
# 220412                                    Other – Write In:
# 220425                                    Other – Write In:
# 220470                                    Other – Write In:
# 220498                                    Other – Write In:
# 220503                                    Other – Write In:
# 220508                                    Other – Write In:
# 220561                                    Other – Write In:
# 220563                                    Other – Write In:
# 220613                                    Other – Write In:
# 220645                                    Other – Write In:
# 220734                                    Other – Write In:
# 220742                                    Other – Write In:
# 220789                                    Other – Write In:
# 220820                                    Other – Write In:
# 220828                                    Other – Write In:
# 220870                                    Other – Write In:
# 220931                                    Other – Write In:
# 221011                                    Other – Write In:
# 221034                                    Other – Write In:
# 221087                                    Other – Write In:
# 221109                                    Other – Write In:
# 221168                                    Other – Write In:
#
# [28938 rows x 1 columns]

# %% [markdown]
# #### Dependent questions
#
# The next two questions are dependent on the answer of question 16
#
# **Quesiton 17**
# >How do you run code in the cloud (in the production environment)?
#
# Spans colums 137 to 142
#
# **Quesiton 18**
# >How do you develop for the cloud?
#
# Spans colums 143 to 151
#
# They are shown only when the user did not choose `None` in question 16. Thus, Nan indicates that:
# - the user does not use any cloud platform
#
#
#
# Nan logic
# ---
#
# When the question is not displayed to the user,  then `Nan` is put as the value, we replace it with `I dont use cloud computing`
#
#
# Let us spend some time automating the processing for both questions in a function

# %%
def reshape_by_replacing_na_and_show_info(question_asked, start_index, end_index, na_str, ):
    untidy_question_df = PYTHON_OBSERVATIONS_DF.iloc[:, start_index:end_index]
    print('---Initial Shape---')
    print(untidy_question_df.shape)

    reshaped_df = \
        reshape_data(untidy_question_df, question_asked=question_asked,fillna_with_str=na_str,dropna=False)
    
    print('---Shape after reshaping---')
    print(reshaped_df.shape)
    print(reshaped_df.iloc[:, 0].value_counts(dropna=False))
    return reshaped_df

# %%
# processing question 17
question_str = 'How do you run code in the cloud (in the production environment)?'
na_str= 'I dont use cloud computing'
sheet_ready_question_seventeen =  \
reshape_by_replacing_na_and_show_info(question_str, 136, 142, na_str)
sheet_ready_question_seventeen.head(10)
# Out:
# ---Initial Shape---
# (18431, 6)
# ---Shape after reshaping---
# (110586, 1)
# I dont use cloud computing                                          93649
# In virtual machines                                                  5308
# Within containers                                                    4461
# On a Platform-as-a-Service (such as Heroku or Google App Engine)     3084
# Serverless (such as AWS Lambda or Cloud Functions)                   2353
# None of the following                                                1451
# Other – Write In:                                                     280
# Name: How do you run code in the cloud (in the production environment)?, dtype: int64
# question How do you run code in the cloud (in the production environment)?
# 0                                I dont use cloud computing
# 1                                I dont use cloud computing
# 2                                I dont use cloud computing
# 3                                I dont use cloud computing
# 4                                I dont use cloud computing
# 5                                I dont use cloud computing
# 6                                I dont use cloud computing
# 7                                I dont use cloud computing
# 8                                I dont use cloud computing
# 9                                I dont use cloud computing

# %%
# processing question 18
question_str = 'How do you develop for the cloud?'
na_str= 'I dont use cloud computing'
sheet_ready_question_eighteen =  \
reshape_by_replacing_na_and_show_info(question_str, 142, 150, na_str)
sheet_ready_question_eighteen.head(10)
# Out:
# ---Initial Shape---
# (18431, 8)
# ---Shape after reshaping---
# (147448, 1)
# I dont use cloud computing                128525
# Locally with virtualenv (or similar)        6317
# In Docker containers                        3940
# In virtual machines                         2728
# With local system interpreter               1959
# In remote development environments          1855
# None of the following                       1042
# Directly in the production environment       968
# Other – Write In:                            114
# Name: How do you develop for the cloud?, dtype: int64
# question How do you develop for the cloud?
# 0               I dont use cloud computing
# 1               I dont use cloud computing
# 2               I dont use cloud computing
# 3               I dont use cloud computing
# 4               I dont use cloud computing
# 5               I dont use cloud computing
# 6               I dont use cloud computing
# 7               I dont use cloud computing
# 8               I dont use cloud computing
# 9               I dont use cloud computing

# %% [markdown]
# #### Question 19
#
# > What operating system(s) are your development environment?
#
# Multi question with columns spanning index 151 to 155. Similar processing

# %%
question_nineteen = 'What operating system(s) are your development environment?'

sheet_ready_question_nineteen = reshape_and_show_info( question_15_str, 150, 155)
sheet_ready_question_nineteen.head(10)
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (27753, 1)
# Linux                12780
# Windows               8703
# macOS                 5806
# BSD                    264
# Other – Write In:      200
# Name: Which of the following frameworks / libraries do you use in addition to Python?, dtype: int64
# question Which of the following frameworks / libraries do you use in addition to Python?
# 3                                                   Windows
# 5                                                   Windows
# 11                                                  Windows
# 14                                                  Windows
# 19                                                  Windows
# 23                                                  Windows
# 26                                                  Windows
# 28                                                  Windows
# 32                                                  Windows
# 36                                                  Windows

# %% [markdown]
# #### Question 20
#
# > Which Python unit-testing framework(s) do you use, if any?
#
# The patterns are now looking the same. From now onwards I would just stop putting the questions in markdowns an would just go straight to extracting the questions

# %%
# Processing Question 20
question_str ='Which Python unit-testing framework(s) do you use, if any?'

sheet_ready_question_twenty = reshape_and_show_info( question_15_str, 155, 164)
sheet_ready_question_twenty.head(10)
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (28787, 1)
# pytest               8448
# None                 6526
# unittest             5873
# mock                 2848
# Tox                  1590
# nose                 1576
# doctest               992
# Hypothesis            659
# Other – Write In:     275
# Name: Which of the following frameworks / libraries do you use in addition to Python?, dtype: int64
# question Which of the following frameworks / libraries do you use in addition to Python?
# 7                                                      None
# 20                                                     None
# 21                                                     None
# 24                                                     None
# 28                                                     None
# 29                                                     None
# 38                                                     None
# 40                                                     None
# 44                                                     None
# 48                                                     None

# %%
# Processing muti-chioce Question 21
question_str ='What ORM(s) do you use together with Python, if any?'

sheet_ready_question_twenty_one = reshape_and_show_info( question_15_str,  164, 173)
sheet_ready_question_twenty_one.head(10)
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (22526, 1)
# None                 7941
# SQLAlchemy           6268
# Django ORM           6010
# SQLObject             771
# Peewee                663
# Other – Write In:     391
# PonyORM               212
# Tortoise ORM          148
# Dejavu                122
# Name: Which of the following frameworks / libraries do you use in addition to Python?, dtype: int64
# question Which of the following frameworks / libraries do you use in addition to Python?
# 0                                                      None
# 2                                                      None
# 7                                                      None
# 8                                                      None
# 12                                                     None
# 13                                                     None
# 19                                                     None
# 25                                                     None
# 26                                                     None
# 27                                                     None

# %%
# Processing muti-chioce Question 22
question_str ='Which database(s) do you regularly use, if any?'

sheet_ready_question_twenty_two = reshape_and_show_info( question_15_str,  173, 189)
sheet_ready_question_twenty_two.head(10)
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (39970, 1)
# PostgreSQL           8133
# MySQL                7562
# SQLite               7530
# MongoDB              3774
# Redis                3488
# None                 2779
# MS SQL Server        1992
# Oracle Database      1396
# Other – Write In:    1144
# Amazon Redshift       555
# Cassandra             480
# Neo4j                 388
# DB2                   249
# HBase                 216
# Couchbase             183
# h2                    101
# Name: Which of the following frameworks / libraries do you use in addition to Python?, dtype: int64
# question Which of the following frameworks / libraries do you use in addition to Python?
# 7                                                      None
# 8                                                      None
# 25                                                     None
# 26                                                     None
# 27                                                     None
# 48                                                     None
# 49                                                     None
# 54                                                     None
# 55                                                     None
# 67                                                     None

# %%
# Processing muti-chioce Question 23
question_str ='Which of the following Big Data tool(s) do you use, if any?'

sheet_ready_question_twenty_three = reshape_and_show_info( question_15_str,  189, 201)
sheet_ready_question_twenty_three.head(10)
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (21722, 1)
# None                       13954
# Apache Spark                2263
# Apache Hadoop/MapReduce     1452
# Apache Kafka                1391
# Apache Hive                  827
# Dask                         760
# Other – Write In:            262
# Apache Beam                  198
# ClickHouse                   195
# Apache Flink                 160
# Apache Tez                   158
# Apache Samza                 102
# Name: Which of the following frameworks / libraries do you use in addition to Python?, dtype: int64
# question Which of the following frameworks / libraries do you use in addition to Python?
# 1                                                      None
# 2                                                      None
# 3                                                      None
# 7                                                      None
# 8                                                      None
# 10                                                     None
# 11                                                     None
# 12                                                     None
# 13                                                     None
# 14                                                     None

# %%
# Processing muti-chioce Question 24
question_str = 'Which Continuous Integration (CI) system(s) do you regularly use?'


sheet_ready_question_twenty_four = reshape_and_show_info( question_str, 201, 211)
sheet_ready_question_twenty_four.head(10)
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (23617, 1)
# None                 8415
# Jenkins / Hudson     4644
# Gitlab CI            3407
# Travis CI            3325
# CircleCI             1319
# Other – Write In:     868
# AppVeyor              591
# TeamCity              479
# Bamboo                468
# CruiseControl         101
# Name: Which Continuous Integration (CI) system(s) do you regularly use?, dtype: int64
# question Which Continuous Integration (CI) system(s) do you regularly use?
# 1                                                      None
# 7                                                      None
# 8                                                      None
# 11                                                     None
# 17                                                     None
# 20                                                     None
# 21                                                     None
# 24                                                     None
# 28                                                     None
# 29                                                     None

# %%
# Processing muti-chioce Question 25
question_str = 'Which configuration management tools do you use, if any?'


sheet_ready_question_twenty_five = reshape_and_show_info( question_str, 211, 218)
sheet_ready_question_twenty_five.head(10)
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (20217, 1)
# None                 11921
# Ansible               3621
# Custom solution       1627
# Puppet                1033
# Salt                   825
# Chef                   669
# Other – Write In:      521
# Name: Which configuration management tools do you use, if any?, dtype: int64
# question Which configuration management tools do you use, if any?
# 1                                                      None
# 2                                                      None
# 5                                                      None
# 7                                                      None
# 8                                                      None
# 9                                                      None
# 12                                                     None
# 14                                                     None
# 16                                                     None
# 18                                                     None

# %%
# Processing muti-chioce Question 26
question_str = 'What is the main editor you use for your current Python development?'
# 

sheet_ready_question_twenty_six = reshape_and_show_info( question_str, 218, 219)
sheet_ready_question_twenty_six.head(10)
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (18431, 1)
# PyCharm Professional Edition             3581
# VS Code                                  2952
# PyCharm Community Edition                2641
# Vim                                      1831
# Sublime Text                             1545
# Jupyter Notebook                          976
# Atom                                      974
# IDLE                                      664
# Emacs                                     564
# Spyder                                    463
# Other – Write In:                         450
# IntelliJ IDEA                             373
# NotePad++                                 343
# Eclipse + Pydev                           312
# None                                      309
# Python Tools for Visual Studio (PTVS)     128
# Wing IDE                                   82
# Gedit                                      80
# NetBeans                                   45
# Komodo Editor                              28
# TextMate                                   23
# Komodo IDE                                 23
# Aptana                                     20
# Ninja-IDE                                  17
# Rodeo                                       7
# Name: What is the main editor you use for your current Python development?, dtype: int64
# question What is the main editor you use for your current Python development?
# 0                                                 NotePad++
# 1                                                   VS Code
# 2                                 PyCharm Community Edition
# 3                                                     Emacs
# 4                                                  Wing IDE
# 5                                                      Atom
# 6                              PyCharm Professional Edition
# 7                              PyCharm Professional Edition
# 8                                         Other – Write In:
# 9                              PyCharm Professional Edition

# %%
# Processing muti-chioce Question 27
question_str = \
'What editors/IDEs do you use for Python development in addition to your main ide/editor?'


sheet_ready_question_twenty_seven = reshape_and_show_info( question_str, 219, 245)
sheet_ready_question_twenty_seven.head(10)
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (34821, 1)
# Vim                                      4581
# Jupyter Notebook                         3881
# Sublime Text                             3460
# VS Code                                  3341
# PyCharm Community Edition                2864
# None                                     2784
# NotePad++                                2745
# Atom                                     2188
# IDLE                                     1676
# PyCharm Professional Edition             1345
# Spyder                                   1044
# Other – Write In:                         876
# Gedit                                     789
# IntelliJ IDEA                             680
# Python Tools for Visual Studio (PTVS)     643
# Emacs                                     564
# Eclipse + Pydev                           536
# NetBeans                                  262
# TextMate                                  148
# Wing IDE                                   91
# Ninja-IDE                                  88
# Komodo Editor                              78
# Komodo IDE                                 72
# Aptana                                     51
# Rodeo                                      34
# Name: What editors/IDEs do you use for Python development in addition to your main ide/editor?, dtype: int64
# question What editors/IDEs do you use for Python development in addition to your main ide/editor?
# 18471                          PyCharm Professional Edition
# 18474                          PyCharm Professional Edition
# 18518                          PyCharm Professional Edition
# 18550                          PyCharm Professional Edition
# 18554                          PyCharm Professional Edition
# 18574                          PyCharm Professional Edition
# 18588                          PyCharm Professional Edition
# 18599                          PyCharm Professional Edition
# 18611                          PyCharm Professional Edition
# 18616                          PyCharm Professional Edition

# %%
# Processing muti-chioce Question 28
question_str = \
'Do you regularly work on multiple projects at the same time?'


sheet_ready_question_twenty_eight = reshape_and_show_info( question_str, 245, 246)
sheet_ready_question_twenty_eight.head(10)
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (18431, 1)
# Yes, I work on many different projects               7756
# Yes, I work on one main and several side projects    7611
# No,  I only work on one project                      3064
# Name: Do you regularly work on multiple projects at the same time?, dtype: int64
# question Do you regularly work on multiple projects at the same time?
# 0         Yes, I work on one main and several side projects
# 1                    Yes, I work on many different projects
# 2         Yes, I work on one main and several side projects
# 3                    Yes, I work on many different projects
# 4                    Yes, I work on many different projects
# 5                    Yes, I work on many different projects
# 6                    Yes, I work on many different projects
# 7                    Yes, I work on many different projects
# 8                           No,  I only work on one project
# 9         Yes, I work on one main and several side projects

# %%
# Processing muti-chioce Question 29

question_str = 'When developing in Python, how often do'


sheet_ready_question_twenty_nine = reshape_and_show_info( question_str,246, 261)
sheet_ready_question_twenty_nine.head(10)
# Out:
# ---Initial Shape---
# (18431, 13)
# ---Shape after reshaping---
# (206902, 1)
# Often                         83423
# Never or<br />Almost never    63155
# From time<br />to time        60324
# Name: When developing in Python, how often do, dtype: int64
# question When developing in Python, how often do
# 0                                          Often
# 3                     Never or<br />Almost never
# 4                                          Often
# 8                                          Often
# 10                                         Often
# 12                    Never or<br />Almost never
# 13                        From time<br />to time
# 15                                         Often
# 16                                         Often
# 17                                         Often

# %%
PYTHON_OBSERVATIONS_DF.iloc[:, 261].value_counts(dropna=False)
# Out:
# Friend / Colleague                 4828
# Search engines                     2708
# School / University                2575
# I don't remember                   2467
# Technical review / Forum / Blog    2273
# Social network                     1259
# Other – Write In:                  1134
# Conference / User Group             525
# NaN                                 353
# Advertising                         309
# Name: How did you first learn aboutyour main ide/editor?, dtype: int64

# %%
PYTHON_OBSERVATIONS_DF.iloc[:, 218].value_counts(dropna=False)
# Out:
# PyCharm Professional Edition             3581
# VS Code                                  2952
# PyCharm Community Edition                2641
# Vim                                      1831
# Sublime Text                             1545
# Jupyter Notebook                          976
# Atom                                      974
# IDLE                                      664
# Emacs                                     564
# Spyder                                    463
# Other – Write In:                         450
# IntelliJ IDEA                             373
# NotePad++                                 343
# Eclipse + Pydev                           312
# None                                      309
# Python Tools for Visual Studio (PTVS)     128
# Wing IDE                                   82
# Gedit                                      80
# NetBeans                                   45
# Komodo Editor                              28
# TextMate                                   23
# Komodo IDE                                 23
# Aptana                                     20
# Ninja-IDE                                  17
# Rodeo                                       7
# Name: What is the main editor you use for your current Python development?, dtype: int64

# %%
obs = PYTHON_OBSERVATIONS_DF.iloc[:, [218,261]]
obs[ obs.iloc[:, 0] == 'None' ]
# Out:
#       What is the main editor you use for your current Python development?  \
# 2468                                                None
# 2656                                                None
# 3201                                                None
# 3302                                                None
# 3466                                                None
# 3794                                                None
# 3835                                                None
# 3920                                                None
# 3938                                                None
# 4011                                                None
# 4107                                                None
# 4108                                                None
# 4158                                                None
# 4177                                                None
# 4183                                                None
# 4231                                                None
# 4283                                                None
# 4290                                                None
# 4298                                                None
# 4367                                                None
# 4386                                                None
# 4401                                                None
# 4573                                                None
# 4640                                                None
# 4666                                                None
# 4720                                                None
# 4738                                                None
# 4757                                                None
# 4775                                                None
# 4814                                                None
# ...                                                  ...
# 18238                                               None
# 18266                                               None
# 18371                                               None
# 18396                                               None
# 18422                                               None
# 18425                                               None
# 18491                                               None
# 18552                                               None
# 18616                                               None
# 18779                                               None
# 18920                                               None
# 18933                                               None
# 18994                                               None
# 19028                                               None
# 19047                                               None
# 19055                                               None
# 19076                                               None
# 19190                                               None
# 19285                                               None
# 19291                                               None
# 19401                                               None
# 19440                                               None
# 19458                                               None
# 19481                                               None
# 19485                                               None
# 19497                                               None
# 19609                                               None
# 19638                                               None
# 19655                                               None
# 19681                                               None
#
#       How did you first learn aboutyour main ide/editor?
# 2468                                                 NaN
# 2656                                                 NaN
# 3201                                                 NaN
# 3302                                                 NaN
# 3466                                                 NaN
# 3794                                                 NaN
# 3835                                                 NaN
# 3920                                                 NaN
# 3938                                                 NaN
# 4011                                                 NaN
# 4107                                                 NaN
# 4108                                                 NaN
# 4158                                                 NaN
# 4177                                                 NaN
# 4183                                                 NaN
# 4231                                                 NaN
# 4283                                                 NaN
# 4290                                                 NaN
# 4298                                                 NaN
# 4367                                                 NaN
# 4386                                                 NaN
# 4401                                                 NaN
# 4573                                                 NaN
# 4640                                                 NaN
# 4666                                                 NaN
# 4720                                                 NaN
# 4738                                                 NaN
# 4757                                                 NaN
# 4775                                                 NaN
# 4814                                                 NaN
# ...                                                  ...
# 18238                                                NaN
# 18266                                                NaN
# 18371                                                NaN
# 18396                                                NaN
# 18422                                                NaN
# 18425                                                NaN
# 18491                                                NaN
# 18552                                                NaN
# 18616                                                NaN
# 18779                                                NaN
# 18920                                                NaN
# 18933                                                NaN
# 18994                                                NaN
# 19028                                                NaN
# 19047                                                NaN
# 19055                                                NaN
# 19076                                                NaN
# 19190                                                NaN
# 19285                                                NaN
# 19291                                                NaN
# 19401                                                NaN
# 19440                                                NaN
# 19458                                                NaN
# 19481                                                NaN
# 19485                                                NaN
# 19497                                                NaN
# 19609                                                NaN
# 19638                                                NaN
# 19655                                                NaN
# 19681                                                NaN
#
# [309 rows x 2 columns]

# %%
obs[pd.isna( obs.iloc[:, -1] )].iloc[:, 0].value_counts(dropna=False)
# obs[ isinstance(obs.iloc[:, -1], float)].iloc[:, -1].value_counts(dropna=False)
# Out:
# None                                     308
# PyCharm Community Edition                  7
# PyCharm Professional Edition               7
# IDLE                                       5
# Sublime Text                               4
# Atom                                       4
# VS Code                                    4
# Eclipse + Pydev                            3
# Vim                                        3
# NotePad++                                  3
# Spyder                                     2
# Python Tools for Visual Studio (PTVS)      1
# Komodo Editor                              1
# IntelliJ IDEA                              1
# Name: What is the main editor you use for your current Python development?, dtype: int64

# %%
PYTHON_OBSERVATIONS_DF.iloc[:, 264].value_counts(dropna=False)
# Out:
# NaN                    10312
# 2-7 people              6036
# 8-12 people             1370
# 13-20 people             429
# 21-40 people             158
# More than 40 people      126
# Name: How many people are in your project team?, dtype: int64

# %%
PYTHON_OBSERVATIONS_DF.iloc[:, 263].value_counts(dropna=False)
# Out:
# Work in a team                               8879
# Work on your own project(s) independently    8846
# Work as an external consultant or trainer     706
# Name: Most of the time, do you ...?, dtype: int64

# %%
# 263
obsve_32 = PYTHON_OBSERVATIONS_DF.iloc[:, 263:265]
obsve_32[obsve_32.iloc[:, 0] == 'Work in a team'].iloc[:,-1].value_counts(dropna=False)
# Out:
# 2-7 people             6036
# 8-12 people            1370
# NaN                     760
# 13-20 people            429
# 21-40 people            158
# More than 40 people     126
# Name: How many people are in your project team?, dtype: int64

# %%
obsve_32[pd.isna(obsve_32.iloc[:, -1])].iloc[:,0].value_counts(dropna=False)
# Out:
# Work on your own project(s) independently    8846
# Work in a team                                760
# Work as an external consultant or trainer     706
# Name: Most of the time, do you ...?, dtype: int64

# %%
# 266
PYTHON_OBSERVATIONS_DF.iloc[:, 265].value_counts(dropna=False)
# Out:
# Fully employed by a company / organization                                                                 11353
# Student                                                                                                     3535
# Freelancer <em>(a person pursuing a profession without a long-term commitment to any one employer)</em>     1136
# Self-employed <em>(a person earning income directly from one's own business, trade, or profession)</em>     1072
# Partially employed by a company / organization                                                               795
# Other – Write In:                                                                                            390
# Retired                                                                                                      150
# Name: What is your employment status?, dtype: int64

# %%
PYTHON_OBSERVATIONS_DF.iloc[:, 266].value_counts(dropna=False)
# Out:
# NaN                6302
# 51–500             3030
# 11–50              2338
# More than 5,000    2330
# 2–10               1484
# 1,001–5,000        1255
# 501–1,000           806
# Just me             609
# Not sure            277
# Name: How many people work for your company / organization?, dtype: int64

# %%
obser = PYTHON_OBSERVATIONS_DF.iloc[:, [266]]
obser
# Out:
#       How many people work for your company / organization?
# 1404                                     More than 5,000
# 1405                                             Just me
# 1406                                              51–500
# 1407                                              51–500
# 1408                                               11–50
# 1409                                                 NaN
# 1410                                                 NaN
# 1411                                                 NaN
# 1412                                                 NaN
# 1413                                     More than 5,000
# 1414                                              51–500
# 1415                                     More than 5,000
# 1416                                               11–50
# 1417                                         1,001–5,000
# 1418                                                2–10
# 1419                                               11–50
# 1420                                              51–500
# 1421                                              51–500
# 1422                                                 NaN
# 1423                                                 NaN
# 1424                                                 NaN
# 1425                                              51–500
# 1426                                                2–10
# 1427                                     More than 5,000
# 1428                                         1,001–5,000
# 1429                                         1,001–5,000
# 1430                                                 NaN
# 1431                                         1,001–5,000
# 1432                                               11–50
# 1433                                                 NaN
# ...                                                  ...
# 19805                                               2–10
# 19806                                             51–500
# 19807                                              11–50
# 19808                                        1,001–5,000
# 19809                                           Not sure
# 19810                                               2–10
# 19811                                            Just me
# 19812                                        1,001–5,000
# 19813                                             51–500
# 19814                                             51–500
# 19815                                             51–500
# 19816                                               2–10
# 19817                                                NaN
# 19818                                        1,001–5,000
# 19819                                               2–10
# 19820                                    More than 5,000
# 19821                                    More than 5,000
# 19822                                                NaN
# 19823                                        1,001–5,000
# 19824                                              11–50
# 19825                                            Just me
# 19826                                                NaN
# 19827                                                NaN
# 19828                                        1,001–5,000
# 19829                                                NaN
# 19830                                              11–50
# 19831                                             51–500
# 19832                                             51–500
# 19833                                                NaN
# 19834                                             51–500
#
# [18431 rows x 1 columns]

# %%
for index, columns in enumerate(raw_data.columns):
    print('#{}: {}'.format(index+1,  columns))
# Out:
# #1: Unnamed: 0
# #2: Is Python the main language you use for your current projects?
# #3: None:What other language(s) do you use?
# #4: Java:What other language(s) do you use?
# #5: JavaScript:What other language(s) do you use?
# #6: C/C++:What other language(s) do you use?
# #7: PHP:What other language(s) do you use?
# #8: C#:What other language(s) do you use?
# #9: Ruby:What other language(s) do you use?
# #10: Bash / Shell:What other language(s) do you use?
# #11: Objective-C:What other language(s) do you use?
# #12: Go:What other language(s) do you use?
# #13: Visual Basic:What other language(s) do you use?
# #14: Scala:What other language(s) do you use?
# #15: SQL:What other language(s) do you use?
# #16: Kotlin:What other language(s) do you use?
# #17: R:What other language(s) do you use?
# #18: Swift:What other language(s) do you use?
# #19: Clojure:What other language(s) do you use?
# #20: Perl:What other language(s) do you use?
# #21: Rust:What other language(s) do you use?
# #22: Groovy:What other language(s) do you use?
# #23: TypeScript:What other language(s) do you use?
# #24: CoffeeScript:What other language(s) do you use?
# #25: HTML/CSS:What other language(s) do you use?
# #26: Other - Write In::What other language(s) do you use?
# #27: For what purposes do you mainly use Python?
# #28: Educational purposes:What do you use Python for?
# #29: Data analysis:What do you use Python for?
# #30: DevOps / System administration / Writing automation scripts:What do you use Python for?
# #31: Software testing / Writing automated tests:What do you use Python for?
# #32: Software prototyping:What do you use Python for?
# #33: Web development:What do you use Python for?
# #34: Machine learning:What do you use Python for?
# #35: Mobile development:What do you use Python for?
# #36: Desktop development:What do you use Python for?
# #37: Computer graphics:What do you use Python for?
# #38: Network programming:What do you use Python for?
# #39: Game development:What do you use Python for?
# #40: Multimedia applications development:What do you use Python for?
# #41: Embedded development:What do you use Python for?
# #42: Programming of web parsers / scrapers / crawlers:What do you use Python for?
# #43: Other - Write In::What do you use Python for?
# #44: Educational purposes:To what extent are you involvedin the following activities?
# #45: Data analysis:To what extent are you involvedin the following activities?
# #46: DevOps / System administration / Writing automation scripts:To what extent are you involvedin the following activities?
# #47: Software testing / Writing automated tests:To what extent are you involvedin the following activities?
# #48: Software prototyping:To what extent are you involvedin the following activities?
# #49: Web development:To what extent are you involvedin the following activities?
# #50: Machine learning:To what extent are you involvedin the following activities?
# #51: Mobile development:To what extent are you involvedin the following activities?
# #52: Desktop development:To what extent are you involvedin the following activities?
# #53: Computer graphics:To what extent are you involvedin the following activities?
# #54: Network programming:To what extent are you involvedin the following activities?
# #55: Game development:To what extent are you involvedin the following activities?
# #56: Multimedia applications development:To what extent are you involvedin the following activities?
# #57: Embedded development:To what extent are you involvedin the following activities?
# #58: Programming of web parsers / scrapers / crawlers:To what extent are you involvedin the following activities?
# #59: Other - Write In::To what extent are you involvedin the following activities?
# #60: What do you use Python for the most?
# #61: Do you consider yourself as a Data-Scientist?
# #62: Which version of Python do you use the most?
# #63: Which version of Python 2 do you use the most?
# #64: Which version of Python 3 do you use the most?
# #65: I dont update:What do you typically use to upgrade your Python version?
# #66: Somebody else manages Python updates for me:What do you typically use to upgrade your Python version?
# #67: Python.org:What do you typically use to upgrade your Python version?
# #68: Build from source:What do you typically use to upgrade your Python version?
# #69: Automatic upgrade via cloud provider:What do you typically use to upgrade your Python version?
# #70: Enthought:What do you typically use to upgrade your Python version?
# #71: Anaconda:What do you typically use to upgrade your Python version?
# #72: ActivePython:What do you typically use to upgrade your Python version?
# #73: Intel Distribution for Python:What do you typically use to upgrade your Python version?
# #74: OS-provided Python (via apt-get, yum, homebrew, etc.):What do you typically use to upgrade your Python version?
# #75: pyenv:What do you typically use to upgrade your Python version?
# #76: pythonz:What do you typically use to upgrade your Python version?
# #77: I use Docker containers:What do you typically use to upgrade your Python version?
# #78: Other  Write In::What do you typically use to upgrade your Python version?
# #79: None:Do you use any of the following tools to isolate Python environments, if any?
# #80: Virtualenv / pipenv:Do you use any of the following tools to isolate Python environments, if any?
# #81: Conda:Do you use any of the following tools to isolate Python environments, if any?
# #82: Docker:Do you use any of the following tools to isolate Python environments, if any?
# #83: Vagrant  / virtual machines:Do you use any of the following tools to isolate Python environments, if any?
# #84: Other  Write In::Do you use any of the following tools to isolate Python environments, if any?
# #85: None:What web frameworks / libraries do you use in addition to Python?
# #86: Django:What web frameworks / libraries do you use in addition to Python?
# #87: TurboGears:What web frameworks / libraries do you use in addition to Python?
# #88: web2py:What web frameworks / libraries do you use in addition to Python?
# #89: Bottle:What web frameworks / libraries do you use in addition to Python?
# #90: CherryPy:What web frameworks / libraries do you use in addition to Python?
# #91: Flask:What web frameworks / libraries do you use in addition to Python?
# #92: Hug:What web frameworks / libraries do you use in addition to Python?
# #93: Pyramid:What web frameworks / libraries do you use in addition to Python?
# #94: Tornado:What web frameworks / libraries do you use in addition to Python?
# #95: Falcon:What web frameworks / libraries do you use in addition to Python?
# #96: Other  Write In::What web frameworks / libraries do you use in addition to Python?
# #97: None:What data science framework(s) do you use in addition to Python?
# #98: NumPy:What data science framework(s) do you use in addition to Python?
# #99: SciPy:What data science framework(s) do you use in addition to Python?
# #100: Pandas:What data science framework(s) do you use in addition to Python?
# #101: Matplotlib:What data science framework(s) do you use in addition to Python?
# #102: Seaborn:What data science framework(s) do you use in addition to Python?
# #103: SciKit-Learn:What data science framework(s) do you use in addition to Python?
# #104: Keras:What data science framework(s) do you use in addition to Python?
# #105: TensorFlow:What data science framework(s) do you use in addition to Python?
# #106: Theano:What data science framework(s) do you use in addition to Python?
# #107: NLTK:What data science framework(s) do you use in addition to Python?
# #108: Gensim:What data science framework(s) do you use in addition to Python?
# #109: Other - Write In::What data science framework(s) do you use in addition to Python?
# #110: None:Which of the following frameworks / libraries do you use in addition to Python?
# #111: Requests:Which of the following frameworks / libraries do you use in addition to Python?
# #112: aiohttp:Which of the following frameworks / libraries do you use in addition to Python?
# #113: PyQT:Which of the following frameworks / libraries do you use in addition to Python?
# #114: PyGTK:Which of the following frameworks / libraries do you use in addition to Python?
# #115: wxPython:Which of the following frameworks / libraries do you use in addition to Python?
# #116: Pillow:Which of the following frameworks / libraries do you use in addition to Python?
# #117: Tkinter:Which of the following frameworks / libraries do you use in addition to Python?
# #118: Pygame:Which of the following frameworks / libraries do you use in addition to Python?
# #119: Twisted:Which of the following frameworks / libraries do you use in addition to Python?
# #120: Asyncio:Which of the following frameworks / libraries do you use in addition to Python?
# #121: Kivy:Which of the following frameworks / libraries do you use in addition to Python?
# #122: Six:Which of the following frameworks / libraries do you use in addition to Python?
# #123: Scrapy:Which of the following frameworks / libraries do you use in addition to Python?
# #124: Other  Write In::Which of the following frameworks / libraries do you use in addition to Python?
# #125: None:Which of the following cloud platforms do you use?
# #126: Google Cloud Platform:Which of the following cloud platforms do you use?
# #127: AWS:Which of the following cloud platforms do you use?
# #128: Microsoft Azure:Which of the following cloud platforms do you use?
# #129: Rackspace:Which of the following cloud platforms do you use?
# #130: Heroku:Which of the following cloud platforms do you use?
# #131: DigitalOcean:Which of the following cloud platforms do you use?
# #132: Linode:Which of the following cloud platforms do you use?
# #133: PythonAnywhere:Which of the following cloud platforms do you use?
# #134: OpenShift:Which of the following cloud platforms do you use?
# #135: OpenStack:Which of the following cloud platforms do you use?
# #136: Other  Write In::Which of the following cloud platforms do you use?
# #137: None of the following:How do you run code in the cloud (in the production environment)?
# #138: In virtual machines:How do you run code in the cloud (in the production environment)?
# #139: Within containers:How do you run code in the cloud (in the production environment)?
# #140: On a Platform-as-a-Service (such as Heroku or Google App Engine):How do you run code in the cloud (in the production environment)?
# #141: Serverless (such as AWS Lambda or Cloud Functions):How do you run code in the cloud (in the production environment)?
# #142: Other  Write In::How do you run code in the cloud (in the production environment)?
# #143: None of the following:How do you develop for the cloud?
# #144: With local system interpreter:How do you develop for the cloud?
# #145: Locally with virtualenv (or similar):How do you develop for the cloud?
# #146: In Docker containers:How do you develop for the cloud?
# #147: In virtual machines:How do you develop for the cloud?
# #148: In remote development environments:How do you develop for the cloud?
# #149: Directly in the production environment:How do you develop for the cloud?
# #150: Other  Write In::How do you develop for the cloud?
# #151: Windows:What operating system(s) are your development environment?
# #152: Linux:What operating system(s) are your development environment?
# #153: macOS:What operating system(s) are your development environment?
# #154: BSD:What operating system(s) are your development environment?
# #155: Other  Write In::What operating system(s) are your development environment?
# #156: None:Which Python unit-testing framework(s) do you use, if any?
# #157: pytest:Which Python unit-testing framework(s) do you use, if any?
# #158: nose:Which Python unit-testing framework(s) do you use, if any?
# #159: unittest:Which Python unit-testing framework(s) do you use, if any?
# #160: doctest:Which Python unit-testing framework(s) do you use, if any?
# #161: Tox:Which Python unit-testing framework(s) do you use, if any?
# #162: Hypothesis:Which Python unit-testing framework(s) do you use, if any?
# #163: mock:Which Python unit-testing framework(s) do you use, if any?
# #164: Other  Write In::Which Python unit-testing framework(s) do you use, if any?
# #165: None:What ORM(s) do you use together with Python, if any?
# #166: Django ORM:What ORM(s) do you use together with Python, if any?
# #167: SQLAlchemy:What ORM(s) do you use together with Python, if any?
# #168: Peewee:What ORM(s) do you use together with Python, if any?
# #169: Dejavu:What ORM(s) do you use together with Python, if any?
# #170: PonyORM:What ORM(s) do you use together with Python, if any?
# #171: SQLObject:What ORM(s) do you use together with Python, if any?
# #172: Tortoise ORM:What ORM(s) do you use together with Python, if any?
# #173: Other  Write In::What ORM(s) do you use together with Python, if any?
# #174: None:Which database(s) do you regularly use, if any?
# #175: DB2:Which database(s) do you regularly use, if any?
# #176: MS SQL Server:Which database(s) do you regularly use, if any?
# #177: MySQL:Which database(s) do you regularly use, if any?
# #178: Oracle Database:Which database(s) do you regularly use, if any?
# #179: PostgreSQL:Which database(s) do you regularly use, if any?
# #180: SQLite:Which database(s) do you regularly use, if any?
# #181: Cassandra:Which database(s) do you regularly use, if any?
# #182: Couchbase:Which database(s) do you regularly use, if any?
# #183: HBase:Which database(s) do you regularly use, if any?
# #184: MongoDB:Which database(s) do you regularly use, if any?
# #185: Neo4j:Which database(s) do you regularly use, if any?
# #186: Redis:Which database(s) do you regularly use, if any?
# #187: Amazon Redshift:Which database(s) do you regularly use, if any?
# #188: h2:Which database(s) do you regularly use, if any?
# #189: Other  Write In::Which database(s) do you regularly use, if any?
# #190: None:Which of the following Big Data tool(s) do you use, if any?
# #191: Apache Beam:Which of the following Big Data tool(s) do you use, if any?
# #192: Apache Flink:Which of the following Big Data tool(s) do you use, if any?
# #193: Apache Hadoop/MapReduce:Which of the following Big Data tool(s) do you use, if any?
# #194: Apache Hive:Which of the following Big Data tool(s) do you use, if any?
# #195: Apache Samza:Which of the following Big Data tool(s) do you use, if any?
# #196: Apache Kafka:Which of the following Big Data tool(s) do you use, if any?
# #197: Apache Spark:Which of the following Big Data tool(s) do you use, if any?
# #198: Apache Tez:Which of the following Big Data tool(s) do you use, if any?
# #199: Dask:Which of the following Big Data tool(s) do you use, if any?
# #200: ClickHouse:Which of the following Big Data tool(s) do you use, if any?
# #201: Other  Write In::Which of the following Big Data tool(s) do you use, if any?
# #202: None:Which Continuous Integration (CI) system(s) do you regularly use?
# #203: Jenkins / Hudson:Which Continuous Integration (CI) system(s) do you regularly use?
# #204: TeamCity:Which Continuous Integration (CI) system(s) do you regularly use?
# #205: Bamboo:Which Continuous Integration (CI) system(s) do you regularly use?
# #206: Travis CI:Which Continuous Integration (CI) system(s) do you regularly use?
# #207: CircleCI:Which Continuous Integration (CI) system(s) do you regularly use?
# #208: CruiseControl:Which Continuous Integration (CI) system(s) do you regularly use?
# #209: Gitlab CI:Which Continuous Integration (CI) system(s) do you regularly use?
# #210: AppVeyor:Which Continuous Integration (CI) system(s) do you regularly use?
# #211: Other  Write In::Which Continuous Integration (CI) system(s) do you regularly use?
# #212: None:Which configuration management tools do you use, if any?
# #213: Salt:Which configuration management tools do you use, if any?
# #214: Puppet:Which configuration management tools do you use, if any?
# #215: Chef:Which configuration management tools do you use, if any?
# #216: Ansible:Which configuration management tools do you use, if any?
# #217: Custom solution:Which configuration management tools do you use, if any?
# #218: Other  Write In::Which configuration management tools do you use, if any?
# #219: What is the main editor you use for your current Python development?
# #220: None:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #221: PyCharm Professional Edition:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #222: PyCharm Community Edition:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #223: Sublime Text:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #224: Vim:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #225: Atom:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #226: VS Code:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #227: Eclipse + Pydev:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #228: Aptana:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #229: Jupyter Notebook:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #230: IntelliJ IDEA:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #231: NotePad++:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #232: IDLE:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #233: Emacs:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #234: Python Tools for Visual Studio (PTVS):What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #235: NetBeans:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #236: Spyder:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #237: Rodeo:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #238: Gedit:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #239: Ninja-IDE:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #240: Komodo Editor:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #241: Komodo IDE:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #242: Wing IDE:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #243: TextMate:What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #244: None:What editors/IDEs do you usefor Python development in addition to your main ide/editor?_1
# #245: Other  Write In::What editors/IDEs do you usefor Python development in addition to your main ide/editor?
# #246: Do youregularly work on multiple projects at the same time?
# #247: use autocompletion  in your editor:When developing in Python, how often do you ?
# #248: use a debugger:When developing in Python, how often do you ?
# #249: refactor your code:When developing in Python, how often do you ?
# #250: use Version Control Systems:When developing in Python, how often do you ?
# #251: use code linting (programs that analyze code for potential errors):When developing in Python, how often do you ?
# #252: use Python virtual environments for your projects:When developing in Python, how often do you ?
# #253: use SQL databases :When developing in Python, how often do you ?
# #254: use NoSQL databases:When developing in Python, how often do you ?
# #255: run / debug or edit code on remote machines (remote hosts, VMs, etc.):When developing in Python, how often do you ?
# #256: use a Python profiler:When developing in Python, how often do you ?
# #257: write tests for your code:When developing in Python, how often do you ?
# #258: use code coverage:When developing in Python, how often do you ?
# #259: use optional type hinting:When developing in Python, how often do you ?
# #260: use Continuous Integration tools:When developing in Python, how often do you ?
# #261: use Issue Trackers:When developing in Python, how often do you ?
# #262: How did you first learn aboutyour main ide/editor?
# #263: How often do you use your main ide/editor?
# #264: Most of the time, do you ...?
# #265: How many people are in your project team?
# #266: What is your employment status?
# #267: How many people work for your company / organization?
# #268: Choose one from the list::Which of the following industries best describes your company's business?
# #269: Choose one from the list::Which of the following industries do you develop for?
# #270: How long have you been working in the IT industry?
# #271: DBA:Which of the following best describes your job role(s)?
# #272: Architect:Which of the following best describes your job role(s)?
# #273: QA engineer:Which of the following best describes your job role(s)?
# #274: Developer / Programmer:Which of the following best describes your job role(s)?
# #275: Technical support:Which of the following best describes your job role(s)?
# #276: Data analyst:Which of the following best describes your job role(s)?
# #277: Business analyst:Which of the following best describes your job role(s)?
# #278: Team lead:Which of the following best describes your job role(s)?
# #279: Product manager:Which of the following best describes your job role(s)?
# #280: CIO / CEO / CTO:Which of the following best describes your job role(s)?
# #281: Systems analyst:Which of the following best describes your job role(s)?
# #282: Other  Write In::Which of the following best describes your job role(s)?
# #283: Could you tell us your age range?
# #284: What country do you live in?

# %%
PYTHON_OBSERVATIONS_DF.iloc[:, [268]]
# Out:
#       Choose one from the list::Which of the following industries do you develop for?
# 1404                                                 NaN
# 1405                                                 NaN
# 1406                                               Other
# 1407                                                 NaN
# 1408                                                 NaN
# 1409                                                 NaN
# 1410                                                 NaN
# 1411                                                 NaN
# 1412                                                 NaN
# 1413                                                 NaN
# 1414                                                 NaN
# 1415                                                 NaN
# 1416                                                 NaN
# 1417                                               Other
# 1418                                                 NaN
# 1419                                           Marketing
# 1420                                                 NaN
# 1421                                                 NaN
# 1422                                                 NaN
# 1423                                                 NaN
# 1424                                                 NaN
# 1425                                                 NaN
# 1426                                                 NaN
# 1427                                                 NaN
# 1428                                                 NaN
# 1429                                                 NaN
# 1430                                                 NaN
# 1431       Information Technology / Software Development
# 1432                                                 NaN
# 1433                                                 NaN
# ...                                                  ...
# 19805                                                NaN
# 19806      Information Technology / Software Development
# 19807                                                NaN
# 19808                                                NaN
# 19809                                                NaN
# 19810      Information Technology / Software Development
# 19811                                                NaN
# 19812                                                NaN
# 19813      Information Technology / Software Development
# 19814                                                NaN
# 19815      Information Technology / Software Development
# 19816                                                NaN
# 19817                                                NaN
# 19818                                                NaN
# 19819                               Service/ Maintenance
# 19820                                                NaN
# 19821                                                NaN
# 19822                                                NaN
# 19823      Information Technology / Software Development
# 19824                                                NaN
# 19825                                                NaN
# 19826                                                NaN
# 19827                                                NaN
# 19828                                                NaN
# 19829                                                NaN
# 19830                                              Other
# 19831      Information Technology / Software Development
# 19832                                                NaN
# 19833                                                NaN
# 19834      Information Technology / Software Development
#
# [18431 rows x 1 columns]

# %%
# !pwd
# Out:
# /Users/ogbuejioforchidiebere/Documents/Programming/Python/Practice/Data Science/JBeansData
